# %% [markdown]
# ## Refining EMP metadata (QIIME mapping files) using Pandas

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
import datetime
import math
from collections import defaultdict

# %%
pd.set_option("display.max_rows", 200)

# %%
pd.options.mode.chained_assignment = None

# %%
# path to list of studies (ct112=all) and path to mapping files directory
path_studies = '/Users/luke/emp/metadata-refine/refine_emp_studies_ct112.txt'
path_mapping = '/Users/luke/emp/metadata-qiime-mapping'
path_taxonomy = '/Users/luke/emp/ontology-ncbi-taxonomy/taxdump/names.dmp'
path_empo = '/Users/luke/emp/metadata-refine/empo_samples_unique.xlsx'
path_quality = '/Users/luke/emp/metadata-refine/emp_studies_quality.xlsx'
path_observations = '/Users/luke/emp/otu-picking/emp_observations_97studies.tsv'
path_empinebi = '/Users/luke/emp/metadata-refine/EMP_in_EBI_20160801.xlsx'
removed_studies = ['1799', '10146']

# %% [markdown]
# ### Functions

# %% [markdown]
# #### Function for merging mapping files and tallying column headers

# %%
def merge_and_tally_mapping_files(path_studies, path_mapping):
    studies = [line.rstrip('\n') for line in open(path_studies)]
    header_counts = defaultdict(int)
    df_merged = pd.DataFrame()
    for study in studies:
        path = '%s/%s_qiime_mapping.tsv' % (path_mapping, study)
        df_single = pd.read_csv(path, sep='\t', header=0, index_col=0, dtype=str)
        for header in df_single.columns:
            header_counts[header] += 1
        df_merged = df_merged.append(df_single, ignore_index=False, verify_integrity=True)
    return df_merged, header_counts

# %% [markdown]
# #### Data munging functions
#
# #### Remove trailing ".0" from numeric value in column of df (convert string-float to string-int)

# %%
def remove_decimal_zero(df, column):
    return [re.sub(r'\.0', '', x) if x is not np.nan else '' for x in df[column]]

# %% [markdown]
# #### Round to hundredths with df.apply(round_hundredths)

# %%
def round_hundredths(x):
    x = float(x)
    if math.isnan(x):
        return x
    else:
        return "%.2f" % x

# %% [markdown]
# ### Read NCBI sample and host taxonomy data

# %%
df_tax = pd.read_csv(path_taxonomy, sep='\t\|\t|\t\|', engine='python', header=None)
del df_tax[4]
df_tax.columns = ['tax_id', 'name_txt', 'unique_name', 'name_class']
df_tax['tax_id'] = df_tax['tax_id'].astype(str)

# %%
# dictionary of tax_id => genbank common name
df_tax_gcn = df_tax[df_tax['name_class'] == 'genbank common name']
dict_gcn = dict(zip(df_tax_gcn.tax_id, df_tax_gcn.name_txt))

# %%
# dictionary of tax_id => scientific name
df_tax_sn = df_tax[df_tax['name_class'] == 'scientific name']
dict_sn = dict(zip(df_tax_sn.tax_id, df_tax_sn.name_txt))

# %% [markdown]
# ### Read updated title and metadata quality info

# %%
df_quality = pd.read_excel(path_quality, index_col=None, dtypes=object)

# %%
# dictionary of study_id => title
dict_title = dict(zip(df_quality.study_id.astype(str), df_quality.title))
# dictionary of study_id => dense_sampling
dict_dense_sampling = dict(zip(df_quality.study_id.astype(str), df_quality.dense_sampling))
# dictionary of study_id => metadata_minimal
dict_metadata_minimal = dict(zip(df_quality.study_id.astype(str), df_quality.metadata_minimal))

# %% [markdown]
# ### Read sequences per sample file

# %%
df_observations = pd.read_csv(path_observations, sep='\t', index_col=None)

# %%
# dictionary of #SampleID => split_libraries
dict_seqs_per_sample = dict(zip(df_observations['#SampleID'], df_observations.split_libraries))

# %% [markdown]
# ### Read EMP_in_EBI

# %%
df_empinebi = pd.read_excel(path_empinebi, index_col=None, dtypes=object)

# %%
# dictionary of study_id => email
list_study_id = [re.sub(r'\.0', '', x) if x is not np.nan else '' for x in df_empinebi.study_id.astype(str)]
dict_email = dict(zip(list_study_id, df_empinebi.Email))

# %% [markdown]
# ### Read and refine mapping file

# %% [markdown]
# #### Read mapping files, tally column headers, and merge into single dataframe

# %%
# main code to merge mapping files and count how often column headers appear (~5 min)
df_merged, header_counts = merge_and_tally_mapping_files(path_studies, path_mapping)

# %%
# change spaces in indexes to periods (for study 905)
df_merged.index = [re.sub(' ', '.', x) for x in df_merged.index]

# %%
# add study_id
df_merged['study_id'] = [re.split(r'\.', x)[0] for x in df_merged.index]

# %% [markdown]
# #### Add EMPO columns to merged all columns and select columns (and covert indexes to lowercase to match biom)

# %%
df_empo = pd.read_excel(path_empo, index_col=0, dtypes=object)
df_empo.study_id = df_empo.study_id.astype(str)

# %%
sampletype_cols = [
    'study_id',
    'env_biome',
    'env_feature',
    'env_matter',
    'sample_type']

# %%
df_union_empo = pd.merge(df_merged, df_empo, how='left', left_on=sampletype_cols, right_on=sampletype_cols)
df_union_empo.index = [x for x in df_merged.index]

# %%
df_union_empo.to_csv('/Users/luke/emp/metadata-refine/emp_qiime_mapping_union_empo.tsv', sep='\t', index_label='#SampleID')

# %% [markdown]
# ## Refined mapping file

# %% [markdown]
# _Sample_
#
# * SampleID -- no changes needed
# * BarcodeSequence -- no changes needed
# * LinkerPrimerSequence -- no changes needed
# * Description -- no changes needed
# * host_subject_id -- no changes needed
#
# _Study_
#
# * study_id -- parsed from SampleID
# * title -- using most updated titles from emp_studies_no_controls_GA_LT.xlsx
#
# _Quality_
#
# * dense_sampling -- whether the study has highly similar samples (from emp_studies_no_controls_GA_LT.xlsx)
# * metadata_minimal -- whether the study has only minimal metadata (from emp_studies_no_controls_GA_LT.xlsx)
# * sequences_per_sample -- number of sequences per sample after split libraries (from emp_observations_97studies.tsv)
# * study_ok -- samples to keep based on studies not in list removed_studies
#
# _Taxonomy_
#
# * taxon_id -- removed trailing ".0", fixed Excel Auto Fill and other typos
# * scientific_name -- deleted values that refer to host or don't match lookup value
# * scientific_name_lookup -- looked up from names.dmp using taxon_id
# * host_taxid -- removed trailing ".0", fixed Excel Auto Fill typos
# * host_common_name -- no changes made, but see lookup value
# * host_common_name_lookup -- looked up from names.dmp using host_taxid
# * host_scientific_name_lookup -- looked up from names.dmp using host_taxid
#
# _Geography_
#
# * collection_timestamp -- removed timestamps after today's date
# * country -- fixed misspellings
# * latitude -- fixed errors
# * longitude -- fixed errors
# * depth -- no changes made
# * altitude -- no changes made
# * elevation -- no changes made
#
# _Ontology_
#
# * env_biome -- fixed errors
# * env_feature -- no changes made -- need additional changes from gDoc
# * env_material -- fixed errors, changed name from "env_matter" -- need additional changes from gDoc
# * empo_0 -- no changes, inherited from emp_qiime_mapping_sampletype_unique_empo.xlsx
# * empo_1 -- no changes, inherited from emp_qiime_mapping_sampletype_unique_empo.xlsx
# * empo_2 -- no changes, inherited from emp_qiime_mapping_sampletype_unique_empo.xlsx
# * empo_3 -- no changes, inherited from emp_qiime_mapping_sampletype_unique_empo.xlsx
#
# _Environment_
#
# * temperature -- using "temp", "temp_environment", made fully numeric
# * ph -- using "ph" (fixed), "ph_cacl2", "sediment_ph", made fully numeric
# * salinity -- using "salinity", "samp_salinity", "sediment_salinity", made fully numeric
# * oxygen -- no changes made
# * nitrogen spp.
# * phosphorus spp.
# * carbon spp.

# %% [markdown]
# ### Create dataframe for refined columns

# %% [markdown]
# #### Sample metadata

# %%
df_refined = pd.DataFrame(index=df_merged.index)
df_refined.index.name = '#SampleID'

# %%
df_refined = df_refined.join(df_merged[['BarcodeSequence', 'LinkerPrimerSequence', 'Description', 'host_subject_id']])

# %% [markdown]
# #### Study metadata

# %%
df_refined['study_id'] = [re.split(r'\.', x)[0] for x in df_merged.index]
df_refined['title'] = [dict_title[x] if x in dict_title else '' for x in df_refined['study_id']]

# %%
# title -- fix Excel Auto Fill typos in 662, 1521, consistent names in 1526, 1714, 1721
# no longer necessary after using dict_title
# df_refined['title'] = df_merged['title']
# df_refined['title'][df_refined['study_id'] == '662'] = 'Intertidal microbes 16s for 2009 and 2010'
# df_refined['title'][df_refined['study_id'] == '1521'] = 'Samples presented at EMP conference June 2011 Shenzhen'
# df_refined['title'][df_refined['study_id'] == '1526'] = 'Recovery of biological soil crust-like microbial communities in previously submerged soils of Glen Canyon'
# df_refined['title'][df_refined['study_id'] == '1714'] = 'Malaysia Pasoh Landuse Logged Forest'
# df_refined['title'][df_refined['study_id'] == '1721'] = 'Thomas soil agricultural enhancement'

# %% [markdown]
# #### Quality metadata

# %%
# adding columns for dense_sampling and metadata_minimal
df_refined['dense_sampling'] = [dict_dense_sampling[x] if x in dict_dense_sampling else '' for x in df_refined['study_id']]
df_refined['metadata_minimal'] = [dict_metadata_minimal[x] if x in dict_metadata_minimal else '' for x in df_refined['study_id']]

# %%
# adding column for sequences_per_sample
df_refined['sequences_per_sample'] = [dict_seqs_per_sample[x] if x in dict_seqs_per_sample else '' for x in df_refined.index]

# %%
df_refined['study_ok'] = ['False' if study in removed_studies else 'True' for study in df_refined.study_id]

# %% [markdown]
# #### Taxonomy metadata
#
# ##### Sample taxonomy

# %%
df_refined = df_refined.join(df_merged[['taxon_id', 'scientific_name']])

# %%
# taxon_id -- remove trailing ".0"
df_refined['taxon_id'] = remove_decimal_zero(df_refined, 'taxon_id')
# taxon_id -- fix Excel Auto Fill typos
# Study ??
df_refined['taxon_id'][df_merged['taxon_id'] == '718309'] = '718308'
df_refined['taxon_id'][df_merged['taxon_id'] == '718310'] = '718308'
df_refined['taxon_id'][df_merged['taxon_id'] == '718311'] = '718308'
df_refined['taxon_id'][df_merged['taxon_id'] == '718312'] = '718308'
df_refined['taxon_id'][df_merged['taxon_id'] == '718313'] = '718308'
df_refined['taxon_id'][df_merged['taxon_id'] == '718314'] = '718308'
df_refined['taxon_id'][df_merged['taxon_id'] == '718315'] = '718308'
df_refined['taxon_id'][df_merged['taxon_id'] == '718316'] = '718308'
df_refined['taxon_id'][df_merged['taxon_id'] == '718317'] = '718308'
# Study 10145 -- beach sand metagenome should be 412757
df_refined['taxon_id'][(df_merged['taxon_id'] == '412758') & (df_refined['study_id'] == '10145')] = '412757'
df_refined['taxon_id'][(df_merged['taxon_id'] == '412760') & (df_refined['study_id'] == '10145')] = '412757'
df_refined['taxon_id'][(df_merged['taxon_id'] == '412762') & (df_refined['study_id'] == '10145')] = '412757'
# Study 10278 -- peat metagenome should be 1799672
df_refined['taxon_id'][df_refined['study_id'] == '10278'] = '1799672'

# %%
# scientific_name_lookup -- look up from names.dmp using taxon_id 
df_refined['scientific_name_lookup'] = [dict_sn[x] if x in dict_sn else '' for x in df_refined['taxon_id']]

# %%
# scientific_name -- delete values that refer to host and not sample
df_refined['scientific_name'][df_refined['study_id'] == '1734'] = np.nan
df_refined['scientific_name'][df_refined['study_id'] == '1795'] = np.nan
df_refined['scientific_name'][df_refined['study_id'] == '1889'] = np.nan
df_refined['scientific_name'][df_refined['study_id'] == '10146'] = np.nan
df_refined['scientific_name'][df_refined['study_id'] == '10245'] = np.nan
df_refined['scientific_name'][df_refined['study_id'] == '10273'] = np.nan
df_refined['scientific_name'][df_refined['study_id'] == '10323'] = np.nan

# scientific_name -- delete values that are close but not quite right
df_refined['scientific_name'][df_refined['study_id'] == '10145'] = np.nan
df_refined['scientific_name'][df_refined['study_id'] == '10156'] = np.nan
df_refined['scientific_name'][df_refined['study_id'] == '10180'] = np.nan
df_refined['scientific_name'][df_refined['study_id'] == '10278'] = np.nan
df_refined['scientific_name'][df_refined['study_id'] == '10308'] = np.nan
df_refined['scientific_name'][df_refined['study_id'] == '10346'] = np.nan

# %%
# Check that lookup and given values match
# If scientific_name given, does it match lookup value?
df_sample_sn = df_refined[[x is not np.nan for x in df_refined['scientific_name']]][['scientific_name', 'scientific_name_lookup']]
df_sample_sn[df_sample_sn['scientific_name'] != df_sample_sn['scientific_name_lookup']]
# Out:
# Empty DataFrame
# Columns: [scientific_name, scientific_name_lookup]
# Index: []

# %% [markdown]
# ##### Host taxonomy

# %%
df_refined = df_refined.join(df_merged[['host_taxid', 'host_common_name']])

# %%
# host_taxid -- remove trailing ".0"
df_refined['host_taxid'] = remove_decimal_zero(df_refined, 'host_taxid')
# host_taxid -- fix Excel Auto Fill typos
# Study 10180 -- all should be soil metagenome (410658)
df_refined['host_taxid'][df_refined['study_id'] == '10180'] = '410658'
# Study 1747 -- Komodo dragons should be 61221
df_refined['host_taxid'][(df_merged['host_taxid'] == '61222') & (df_refined['study_id'] == '1747')] = '61221'
df_refined['host_taxid'][(df_merged['host_taxid'] == '61223') & (df_refined['study_id'] == '1747')] = '61221'
df_refined['host_taxid'][(df_merged['host_taxid'] == '61224') & (df_refined['study_id'] == '1747')] = '61221'
df_refined['host_taxid'][(df_merged['host_taxid'] == '61225') & (df_refined['study_id'] == '1747')] = '61221'
df_refined['host_taxid'][(df_merged['host_taxid'] == '61226') & (df_refined['study_id'] == '1747')] = '61221'
df_refined['host_taxid'][(df_merged['host_taxid'] == '61227') & (df_refined['study_id'] == '1747')] = '61221'
# Study 1056 -- Nine-banded armadillio should be 9361
df_refined['host_taxid'][df_refined['host_common_name'] == 'Nine-banded armadillo'] = '9361'

# %%
# host_common_name_lookup -- look up from names.dmp using host_taxid 
df_refined['host_common_name_lookup'] = [dict_gcn[x] if x in dict_gcn else '' for x in df_refined['host_taxid']]
# host_scientific_name_lookup -- look up from names.dmp using host_taxid 
df_refined['host_scientific_name_lookup'] = [dict_sn[x] if x in dict_sn else '' for x in df_refined['host_taxid']]

# %% [markdown]
# #### Geography metadata

# %%
# collection_timestamp
today = datetime.datetime.today()
df_refined['collection_timestamp'] = (df_merged['collection_timestamp'][(df_merged['collection_timestamp'].apply(pd.Timestamp) < today)]).apply(pd.Timestamp)
# country
df_refined['country'] = df_merged['country']
# fix misspellings
df_refined['country'][df_merged['country'] == 'USA'] = 'GAZ:United States of America'
df_refined['country'][df_merged['country'] == 'GAZ:USA'] = 'GAZ:United States of America'
df_refined['country'][df_merged['country'] == 'GAZ: United states of america'] = 'GAZ:United States of America'
df_refined['country'][df_merged['country'] == 'GAZ:United Staates of America'] = 'GAZ:United States of America'
df_refined['country'][df_merged['country'] == 'Kenya'] = 'GAZ:Kenya'
df_refined['country'][df_merged['country'] == 'Canada'] = 'GAZ:Canada'
df_refined['country'][df_merged['country'] == 'GAZ:Arctic ocean'] = 'GAZ:Arctic Ocean'
df_refined['country'][df_merged['country'] == 'GAZ:russia'] = 'GAZ:Russia'
df_refined['country'][df_merged['country'] == 'GAZ:Commonwealth of Puerto Rico'] = 'GAZ:Puerto Rico'

# %%
# latitude, longitude
df_refined['latitude'] = df_merged['latitude']
df_refined['longitude'] = df_merged['longitude']
# change 0.0 to NaN (studies 1197, 1526, 1632, 1665, 1734, 1883)
df_refined['latitude'][df_merged['latitude'] == '0.0'] = np.nan
df_refined['longitude'][df_merged['longitude'] == '0.0'] = np.nan
# change 9999.0 to NaN (study 10156)
df_refined['latitude'][df_merged['latitude'] == '9999.0'] = np.nan
df_refined['longitude'][df_merged['longitude'] == '9999.0'] = np.nan
# divide by 100 for value > 10000 (study 933) -- Gail will fix in Qiita
for index, value in df_merged['longitude'].iteritems():
    if float(value) > 10000:
        df_refined['longitude'][index] = str(float(value)*0.01)

# %%
# depth, altitude, and elevation
df_refined = df_refined.join(df_merged[['depth', 'altitude', 'elevation']])

# %% [markdown]
# #### Ontology metadata

# %%
# change to dictionary with replace (unless study id is required)

# %%
# env_biome, env_feature, env_material
# gdoc: https://docs.google.com/spreadsheets/d/1Xqmelnbx5PahFh4PoWEOo4zup9qwg52GR82Jrj313Os/edit?usp=sharing
df_refined['env_biome'] = df_merged['env_biome']
df_refined['env_feature'] = df_merged['env_feature']
df_refined['env_material'] = df_merged['env_matter']

# env_biome fixes -- still need to reassign several -- see highlighted rows in gDoc
df_refined['env_biome'][df_merged['env_biome'] == 'ENVO:cropland'] = 'ENVO:cropland biome'
df_refined['env_biome'][df_merged['env_biome'] == 'ENVO:small river biome'] = 'ENVO:Small river biome'
df_refined['env_biome'][df_merged['env_biome'] == 'ENVO:small river biome biome'] = 'ENVO:Small river biome'
df_refined['env_biome'][df_merged['env_biome'] == 'ENVO:small lake biome'] = 'ENVO:Small lake biome'
df_refined['env_biome'][df_merged['env_biome'] == 'ENVOSmall lake biome'] = 'ENVO:Small lake biome'
df_refined['env_biome'][df_merged['env_biome'] == 'small lake biome'] = 'ENVO:Small lake biome'
df_refined['env_biome'][df_merged['env_biome'] == 'ENVO:large river biome'] = 'ENVO:Large river biome'
df_refined['env_biome'][df_merged['env_biome'] == 'ENVO:mediterranean forests, woodlands, and shrub biome'] = 'ENVO:mediterranean woodland biome'
df_refined['env_biome'][df_merged['env_biome'] == 'marginal sea'] = 'ENVO:marginal sea biome'
df_refined['env_biome'][df_merged['env_biome'] == 'marine benthic biome'] = 'ENVO:marine benthic biome'
df_refined['env_biome'][df_merged['env_biome'] == 'estuarine biome'] = 'ENVO:estuarine biome'
# Study 723 should be 'marine pelagic biome' instead of 'polar biome'
df_refined['env_biome'][df_refined['study_id'] == '723'] = 'ENVO:marine pelagic biome'
# Studies 776, 1033 should be 'polar desert biome' instead of 'polar biome'
df_refined['env_biome'][df_refined['study_id'] == '776'] = 'ENVO:polar desert biome'
df_refined['env_biome'][df_refined['study_id'] == '1033'] = 'ENVO:polar desert biome'
# Studies 1036 should be 'tundra biome' instead of 'polar biome'
df_refined['env_biome'][df_refined['study_id'] == '1036'] = 'ENVO:tundra biome'
# Study 632 reassign defunct categories
df_refined['env_biome'][(df_refined['study_id'] == '632') & (df_refined['env_biome'] == 'ENVO:temperate broadleaf and mixed forest biome')] = 'ENVO:temperate mixed forest biome'
df_refined['env_biome'][(df_refined['study_id'] == '632') & (df_refined['env_biome'] == 'ENVO:temperate grasslands, savannas, and shrubland biome')] = 'ENVO:temperate grasslands biome'
# Study 1521 reassign defunct categories
df_refined['env_biome'][(df_refined['study_id'] == '1521') & (df_refined['env_biome'] == 'ENVO:temperate broadleaf and mixed forest biome')] = 'ENVO:temperate mixed forest biome'
# Study 1037 reassign defunct categories
df_refined['env_biome'][(df_refined['study_id'] == '1037') & (df_refined['env_biome'] == 'ENVO:temperate grasslands, savannas, and shrubland biome')] = 'ENVO:temperate grasslands biome'

# env_feature fixes -- NOT DONE, lots of questionable classifications -- see gDoc

# env_material fixes -- still need to reassign several -- see highlighted rows in gDoc
df_refined['env_material'][df_merged['env_matter'] == 'ENVO:egg'] = 'ENVO:avian egg product'
df_refined['env_material'][df_merged['env_matter'] == 'ENVO:oraganic material'] = 'ENVO:organic material'
df_refined['env_material'][df_merged['env_matter'] == 'ENVO:organic material feature'] = 'ENVO:organic material'
df_refined['env_material'][df_merged['env_matter'] == 'ENVO:surface'] = 'ENVO:surface layer'
df_refined['env_material'][df_merged['env_matter'] == 'sea water'] = 'ENVO:sea water'
df_refined['env_material'][df_merged['env_matter'] == 'marine sediment'] = 'ENVO:marine sediment'
df_refined['env_material'][df_merged['env_matter'] == 'estuary water'] = 'ENVO:estuary water'
df_refined['env_material'][df_merged['env_matter'] == 'fresh water'] = 'ENVO:fresh water'
df_refined['env_material'][df_merged['env_matter'] == 'hypersaline water'] = 'ENVO:hypersaline water'
df_refined['env_material'][df_merged['env_matter'] == 'sediment'] = 'ENVO:sediment'
df_refined['env_material'][df_merged['env_matter'] == 'fresh water sediment'] = 'ENVO:lake sediment'
df_refined['env_material'][df_merged['env_matter'] == 'ENVO: freshwater sediment'] = 'ENVO:lake sediment'
df_refined['env_material'][df_merged['env_matter'] == 'estuary sediment'] = 'ENVO:estuary sediment'

# removing "ENVO:"
df_refined['env_biome'] = [re.sub('ENVO:', '', string) for string in df_refined['env_biome']]
df_refined['env_feature'] = [re.sub('ENVO:', '', string) for string in df_refined['env_feature']]
df_refined['env_material'] = [re.sub('ENVO:', '', string) for string in df_refined['env_material']]

# %%
# empo_*
# No changes needed. Specified directly by Excel file, in which I manually assigned EMPO categories to 
# each unique combination of env_biome, env_feature, env_matter, and sample_type.
df_refined = df_refined.join(df_union_empo[['empo_0', 'empo_1', 'empo_2', 'empo_3']])

# %% [markdown]
# #### Environment metadata

# %%
# temperature -- using temp, temp_environment
df_refined['temperature'] = df_merged['temp']
# change None and No data to np.nan
df_refined['temperature'][df_merged['temp'] == 'None'] = np.nan
df_refined['temperature'][df_merged['temp'] == 'No data'] = np.nan
# use temp_environment if refined temperature is NaN
df_refined['temperature'][(df_refined['temperature']).isnull()] = df_merged['temp_enviromnment'][(df_refined['temperature']).isnull()]
# remove '0.0' values for Study 10247
df_refined['temperature'][(df_refined['temperature'] == '0.0') & (df_refined['study_id'] == '10247')] = np.nan

# %%
# ph -- using ph, ph_cacl2, and sediment_ph
df_refined['ph'] = df_merged['ph']
# change None and NaN to np.nan
df_refined['ph'][df_merged['ph'] == 'NaN'] = np.nan
df_refined['ph'][df_merged['ph'] == 'None'] = np.nan
# change 9999.0 to NaN
df_refined['ph'][df_merged['ph'] == '9999.0'] = np.nan
# change 8.08 +- 0.21 to 8.08
df_refined['ph'][df_merged['ph'] == '8.08 +- 0.21'] = '8.08'
# round ph for Study 10246 to hundredths place
df_refined['ph'][df_refined['study_id'] == '10246'] = df_refined['ph'][df_refined['study_id'] == '10246'].apply(round_hundredths)
# pull ph from oxygen_percent if #SampleID starts with 945 and lake == Fuchskuhle -- Gail will fix in Qiita
df_refined['ph'][df_merged['lake'] == 'Fuchskuhle'] = df_merged[df_merged['lake'] == 'Fuchskuhle']['oxygen_percent']
# use ph_cacl2 if refined ph is NaN
df_refined['ph'][(df_refined['ph']).isnull()] = df_merged['ph_cacl2'][(df_refined['ph']).isnull()]
# use sediment_ph if refined ph is still NaN
df_refined['ph'][(df_refined['ph']).isnull()] = df_merged['sediment_ph'][(df_refined['ph']).isnull()]

# %%
# salinity -- using salinity, samp_salinity, sediment_salinity
df_refined['salinity'] = df_merged['salinity']
# change None to np.nan
df_refined['salinity'][df_merged['salinity'] == 'None'] = np.nan
# use samp_salinity if refined salinity is NaN
df_refined['salinity'][(df_refined['salinity']).isnull()] = df_merged['samp_salinity'][(df_refined['salinity']).isnull()]
# use sediment_salinity if refined salinity is NaN
df_refined['salinity'][(df_refined['salinity']).isnull()] = df_merged['sediment_salinity'][(df_refined['salinity']).isnull()]
# covert ppm to ppt for 3 samples in Study 10145
df_refined['salinity']['10145.NB.1A'] = '0.0657'
df_refined['salinity']['10145.7th.1A'] = '0.199'
df_refined['salinity']['10145.7th.1C'] = '0.831'
# remove '0.0' values for Study 10247
df_refined['salinity'][(df_refined['salinity'] == '0.0') & (df_refined['study_id'] == '10247')] = np.nan

# %%
# oxygen
df_refined['oxygen'] = df_merged['oxygen']

# %% [markdown]
# ### Additional metadata columns (in progress)

# %%
# phosphorus -- don't know units!
phos_variants = []
for header in header_counts_keys:
    if re.search(r'phos|tot_p|ppm_p', header, re.IGNORECASE):
        phos_variants.append(header)
df_phos = df_merged[phos_variants].dropna(how='all')
df_phos.iloc[np.arange(0, df_phos.shape[0], 100)]
# Out:
#                                                    phosplipid_fatt_acid  \
# #SampleID
# 638.ELB15.111810.1                                                  NaN
# 678.OA.mesocosm.433                                                 NaN
# 723.C8.0m.G3.Catlin1.16Spool.110602.HWI.EAS137R...                  NaN
# 755.LAB.IN.02.06.11.lane1.NoIndex.L001                              NaN
# 905.PLO6.t2.OX.0to1cm.3                                             NaN
# 1197.SE.20101011.GY.D064S.BC.245.a                                  NaN
# 1222.B5.5.16.06                                                     NaN
# 1240.1307T                                                          NaN
# 1481.PO4.4.T0                                                       NaN
# 1674.McG.F110714Ch2R5                                               NaN
# 1674.McG.G110718Ha6                                                 NaN
# 1715.McG.NS2                                                        NaN
# 1717.3.improved.leguminous                                          NaN
# 1721.R15M                                                           NaN
# 1721.S20B                                                           NaN
# 1883.2011.139.Crump.Artic.LTREB.main.lane3.NoIndex                  NaN
# 1883.2007.043.Crump.Artic.LTREB.main.lane1.NoIndex                  NaN
# 1883.2010.224.Crump.Artic.LTREB.main.lane3.NoIndex                  NaN
# 1883.2004.066.Crump.Artic.LTREB.main.lane1.NoIndex                  NaN
# 1883.2009.259.Crump.Artic.LTREB.main.lane2.NoIndex                  NaN
# 1883.2001.089.Crump.Artic.LTREB.main.lane1.NoIndex                  NaN
# 1883.2008.37.Crump.Artic.LTREB.main.lane2.NoIndex                   NaN
# 1883.2010.359.Crump.Artic.LTREB.main.lane3.NoIndex                  NaN
# 1883.2004.028.Crump.Artic.LTREB.main.lane1.NoIndex                  NaN
# 1883.2009.249.Crump.Artic.LTREB.main.lane2.NoIndex                  NaN
# 1883.2002.104.Crump.Artic.LTREB.main.lane1.NoIndex                  NaN
# 1883.2008.049.Crump.Artic.LTREB.main.lane2.NoIndex                  NaN
# 1883.2002.046.Crump.Artic.LTREB.main.lane1.NoIndex                  NaN
# 1883.2006.104.Crump.Artic.LTREB.main.lane1.NoIndex                  NaN
# 2080.S39D2585                                                       NaN
# 10180.G5I                                                           NaN
# 10245.40.Drnum4.day15.Bag10                                         NaN
#
#                                                    urine_tot_polyphenols  \
# #SampleID
# 638.ELB15.111810.1                                                   NaN
# 678.OA.mesocosm.433                                                  NaN
# 723.C8.0m.G3.Catlin1.16Spool.110602.HWI.EAS137R...                   NaN
# 755.LAB.IN.02.06.11.lane1.NoIndex.L001                               NaN
# 905.PLO6.t2.OX.0to1cm.3                                              NaN
# 1197.SE.20101011.GY.D064S.BC.245.a                                   NaN
# 1222.B5.5.16.06                                                      NaN
# 1240.1307T                                                           NaN
# 1481.PO4.4.T0                                                148041.4654
# 1674.McG.F110714Ch2R5                                                NaN
# 1674.McG.G110718Ha6                                                  NaN
# 1715.McG.NS2                                                         NaN
# 1717.3.improved.leguminous                                           NaN
# 1721.R15M                                                            NaN
# 1721.S20B                                                            NaN
# 1883.2011.139.Crump.Artic.LTREB.main.lane3.NoIndex                   NaN
# 1883.2007.043.Crump.Artic.LTREB.main.lane1.NoIndex                   NaN
# 1883.2010.224.Crump.Artic.LTREB.main.lane3.NoIndex                   NaN
# 1883.2004.066.Crump.Artic.LTREB.main.lane1.NoIndex                   NaN
# 1883.2009.259.Crump.Artic.LTREB.main.lane2.NoIndex                   NaN
# 1883.2001.089.Crump.Artic.LTREB.main.lane1.NoIndex                   NaN
# 1883.2008.37.Crump.Artic.LTREB.main.lane2.NoIndex                    NaN
# 1883.2010.359.Crump.Artic.LTREB.main.lane3.NoIndex                   NaN
# 1883.2004.028.Crump.Artic.LTREB.main.lane1.NoIndex                   NaN
# 1883.2009.249.Crump.Artic.LTREB.main.lane2.NoIndex                   NaN
# 1883.2002.104.Crump.Artic.LTREB.main.lane1.NoIndex                   NaN
# 1883.2008.049.Crump.Artic.LTREB.main.lane2.NoIndex                   NaN
# 1883.2002.046.Crump.Artic.LTREB.main.lane1.NoIndex                   NaN
# 1883.2006.104.Crump.Artic.LTREB.main.lane1.NoIndex                   NaN
# 2080.S39D2585                                                        NaN
# 10180.G5I                                                            NaN
# 10245.40.Drnum4.day15.Bag10                                          NaN
#
#                                                    tot_p ppm_pb  \
# #SampleID
# 638.ELB15.111810.1                                   NaN    NaN
# 678.OA.mesocosm.433                                  NaN    NaN
# 723.C8.0m.G3.Catlin1.16Spool.110602.HWI.EAS137R...   NaN    NaN
# 755.LAB.IN.02.06.11.lane1.NoIndex.L001               NaN    NaN
# 905.PLO6.t2.OX.0to1cm.3                              NaN    NaN
# 1197.SE.20101011.GY.D064S.BC.245.a                   NaN    NaN
# 1222.B5.5.16.06                                      NaN    NaN
# 1240.1307T                                           NaN    NaN
# 1481.PO4.4.T0                                        NaN    NaN
# 1674.McG.F110714Ch2R5                                NaN  4.347
# 1674.McG.G110718Ha6                                  NaN  7.909
# 1715.McG.NS2                                         NaN   <0.1
# 1717.3.improved.leguminous                           NaN    NaN
# 1721.R15M                                            NaN    NaN
# 1721.S20B                                            NaN    NaN
# 1883.2011.139.Crump.Artic.LTREB.main.lane3.NoIndex   NaN    NaN
# 1883.2007.043.Crump.Artic.LTREB.main.lane1.NoIndex   NaN    NaN
# 1883.2010.224.Crump.Artic.LTREB.main.lane3.NoIndex   NaN    NaN
# 1883.2004.066.Crump.Artic.LTREB.main.lane1.NoIndex   NaN    NaN
# 1883.2009.259.Crump.Artic.LTREB.main.lane2.NoIndex   NaN    NaN
# 1883.2001.089.Crump.Artic.LTREB.main.lane1.NoIndex   NaN    NaN
# 1883.2008.37.Crump.Artic.LTREB.main.lane2.NoIndex    NaN    NaN
# 1883.2010.359.Crump.Artic.LTREB.main.lane3.NoIndex   NaN    NaN
# 1883.2004.028.Crump.Artic.LTREB.main.lane1.NoIndex   NaN    NaN
# 1883.2009.249.Crump.Artic.LTREB.main.lane2.NoIndex   NaN    NaN
# 1883.2002.104.Crump.Artic.LTREB.main.lane1.NoIndex   NaN    NaN
# 1883.2008.049.Crump.Artic.LTREB.main.lane2.NoIndex   NaN    NaN
# 1883.2002.046.Crump.Artic.LTREB.main.lane1.NoIndex   NaN    NaN
# 1883.2006.104.Crump.Artic.LTREB.main.lane1.NoIndex   NaN    NaN
# 2080.S39D2585                                        NaN    NaN
# 10180.G5I                                            NaN    NaN
# 10245.40.Drnum4.day15.Bag10                          NaN    NaN
#
#                                                    bray_phosphorus_mg_kg  \
# #SampleID
# 638.ELB15.111810.1                                                   NaN
# 678.OA.mesocosm.433                                                  NaN
# 723.C8.0m.G3.Catlin1.16Spool.110602.HWI.EAS137R...                   NaN
# 755.LAB.IN.02.06.11.lane1.NoIndex.L001                               NaN
# 905.PLO6.t2.OX.0to1cm.3                                              NaN
# 1197.SE.20101011.GY.D064S.BC.245.a                                   NaN
# 1222.B5.5.16.06                                                      NaN
# 1240.1307T                                                           NaN
# 1481.PO4.4.T0                                                        NaN
# 1674.McG.F110714Ch2R5                                                NaN
# 1674.McG.G110718Ha6                                                  NaN
# 1715.McG.NS2                                                         NaN
# 1717.3.improved.leguminous                                           NaN
# 1721.R15M                                                            9.5
# 1721.S20B                                                            8.5
# 1883.2011.139.Crump.Artic.LTREB.main.lane3.NoIndex                   NaN
# 1883.2007.043.Crump.Artic.LTREB.main.lane1.NoIndex                   NaN
# 1883.2010.224.Crump.Artic.LTREB.main.lane3.NoIndex                   NaN
# 1883.2004.066.Crump.Artic.LTREB.main.lane1.NoIndex                   NaN
# 1883.2009.259.Crump.Artic.LTREB.main.lane2.NoIndex                   NaN
# 1883.2001.089.Crump.Artic.LTREB.main.lane1.NoIndex                   NaN
# 1883.2008.37.Crump.Artic.LTREB.main.lane2.NoIndex                    NaN
# 1883.2010.359.Crump.Artic.LTREB.main.lane3.NoIndex                   NaN
# 1883.2004.028.Crump.Artic.LTREB.main.lane1.NoIndex                   NaN
# 1883.2009.249.Crump.Artic.LTREB.main.lane2.NoIndex                   NaN
# 1883.2002.104.Crump.Artic.LTREB.main.lane1.NoIndex                   NaN
# 1883.2008.049.Crump.Artic.LTREB.main.lane2.NoIndex                   NaN
# 1883.2002.046.Crump.Artic.LTREB.main.lane1.NoIndex                   NaN
# 1883.2006.104.Crump.Artic.LTREB.main.lane1.NoIndex                   NaN
# 2080.S39D2585                                                        NaN
# 10180.G5I                                                            NaN
# 10245.40.Drnum4.day15.Bag10                                          NaN
#
#                                                    colwell_phosphorus_mg_kg  \
# #SampleID
# 638.ELB15.111810.1                                                      NaN
# 678.OA.mesocosm.433                                                     NaN
# 723.C8.0m.G3.Catlin1.16Spool.110602.HWI.EAS137R...                      NaN
# 755.LAB.IN.02.06.11.lane1.NoIndex.L001                                  NaN
# 905.PLO6.t2.OX.0to1cm.3                                                 NaN
# 1197.SE.20101011.GY.D064S.BC.245.a                                      NaN
# 1222.B5.5.16.06                                                         NaN
# 1240.1307T                                                              NaN
# 1481.PO4.4.T0                                                           NaN
# 1674.McG.F110714Ch2R5                                                   NaN
# 1674.McG.G110718Ha6                                                     NaN
# 1715.McG.NS2                                                            NaN
# 1717.3.improved.leguminous                                              NaN
# 1721.R15M                                                              50.0
# 1721.S20B                                                              45.0
# 1883.2011.139.Crump.Artic.LTREB.main.lane3.NoIndex                      NaN
# 1883.2007.043.Crump.Artic.LTREB.main.lane1.NoIndex                      NaN
# 1883.2010.224.Crump.Artic.LTREB.main.lane3.NoIndex                      NaN
# 1883.2004.066.Crump.Artic.LTREB.main.lane1.NoIndex                      NaN
# 1883.2009.259.Crump.Artic.LTREB.main.lane2.NoIndex                      NaN
# 1883.2001.089.Crump.Artic.LTREB.main.lane1.NoIndex                      NaN
# 1883.2008.37.Crump.Artic.LTREB.main.lane2.NoIndex                       NaN
# 1883.2010.359.Crump.Artic.LTREB.main.lane3.NoIndex                      NaN
# 1883.2004.028.Crump.Artic.LTREB.main.lane1.NoIndex                      NaN
# 1883.2009.249.Crump.Artic.LTREB.main.lane2.NoIndex                      NaN
# 1883.2002.104.Crump.Artic.LTREB.main.lane1.NoIndex                      NaN
# 1883.2008.049.Crump.Artic.LTREB.main.lane2.NoIndex                      NaN
# 1883.2002.046.Crump.Artic.LTREB.main.lane1.NoIndex                      NaN
# 1883.2006.104.Crump.Artic.LTREB.main.lane1.NoIndex                      NaN
# 2080.S39D2585                                                           NaN
# 10180.G5I                                                               NaN
# 10245.40.Drnum4.day15.Bag10                                             NaN
#
#                                                    tot_diss_phosphorus  \
# #SampleID
# 638.ELB15.111810.1                                                 NaN
# 678.OA.mesocosm.433                                                NaN
# 723.C8.0m.G3.Catlin1.16Spool.110602.HWI.EAS137R...                 NaN
# 755.LAB.IN.02.06.11.lane1.NoIndex.L001                             NaN
# 905.PLO6.t2.OX.0to1cm.3                                            NaN
# 1197.SE.20101011.GY.D064S.BC.245.a                                 NaN
# 1222.B5.5.16.06                                                    NaN
# 1240.1307T                                                         NaN
# 1481.PO4.4.T0                                                      NaN
# 1674.McG.F110714Ch2R5                                              NaN
# 1674.McG.G110718Ha6                                                NaN
# 1715.McG.NS2                                                       NaN
# 1717.3.improved.leguminous                                         NaN
# 1721.R15M                                                          NaN
# 1721.S20B                                                          NaN
# 1883.2011.139.Crump.Artic.LTREB.main.lane3.NoIndex                 NaN
# 1883.2007.043.Crump.Artic.LTREB.main.lane1.NoIndex                 0.2
# 1883.2010.224.Crump.Artic.LTREB.main.lane3.NoIndex                 0.1
# 1883.2004.066.Crump.Artic.LTREB.main.lane1.NoIndex                 0.1
# 1883.2009.259.Crump.Artic.LTREB.main.lane2.NoIndex                 0.2
# 1883.2001.089.Crump.Artic.LTREB.main.lane1.NoIndex                 0.1
# 1883.2008.37.Crump.Artic.LTREB.main.lane2.NoIndex                  0.0
# 1883.2010.359.Crump.Artic.LTREB.main.lane3.NoIndex                 0.1
# 1883.2004.028.Crump.Artic.LTREB.main.lane1.NoIndex                 0.0
# 1883.2009.249.Crump.Artic.LTREB.main.lane2.NoIndex                 0.1
# 1883.2002.104.Crump.Artic.LTREB.main.lane1.NoIndex                 0.1
# 1883.2008.049.Crump.Artic.LTREB.main.lane2.NoIndex                 0.1
# 1883.2002.046.Crump.Artic.LTREB.main.lane1.NoIndex                 0.1
# 1883.2006.104.Crump.Artic.LTREB.main.lane1.NoIndex                 0.0
# 2080.S39D2585                                                      NaN
# 10180.G5I                                                          NaN
# 10245.40.Drnum4.day15.Bag10                                        NaN
#
#                                                    phospho_lipid_fatt_acid  \
# #SampleID
# 638.ELB15.111810.1                                                     NaN
# 678.OA.mesocosm.433                                                    NaN
# 723.C8.0m.G3.Catlin1.16Spool.110602.HWI.EAS137R...                     NaN
# 755.LAB.IN.02.06.11.lane1.NoIndex.L001                                 NaN
# 905.PLO6.t2.OX.0to1cm.3                                                NaN
# 1197.SE.20101011.GY.D064S.BC.245.a                                     NaN
# 1222.B5.5.16.06                                                        NaN
# 1240.1307T                                                             NaN
# 1481.PO4.4.T0                                                          NaN
# 1674.McG.F110714Ch2R5                                                  NaN
# 1674.McG.G110718Ha6                                                    NaN
# 1715.McG.NS2                                                           NaN
# 1717.3.improved.leguminous                                             NaN
# 1721.R15M                                                              NaN
# 1721.S20B                                                              NaN
# 1883.2011.139.Crump.Artic.LTREB.main.lane3.NoIndex                     NaN
# 1883.2007.043.Crump.Artic.LTREB.main.lane1.NoIndex                     NaN
# 1883.2010.224.Crump.Artic.LTREB.main.lane3.NoIndex                     NaN
# 1883.2004.066.Crump.Artic.LTREB.main.lane1.NoIndex                     NaN
# 1883.2009.259.Crump.Artic.LTREB.main.lane2.NoIndex                     NaN
# 1883.2001.089.Crump.Artic.LTREB.main.lane1.NoIndex                     NaN
# 1883.2008.37.Crump.Artic.LTREB.main.lane2.NoIndex                      NaN
# 1883.2010.359.Crump.Artic.LTREB.main.lane3.NoIndex                     NaN
# 1883.2004.028.Crump.Artic.LTREB.main.lane1.NoIndex                     NaN
# 1883.2009.249.Crump.Artic.LTREB.main.lane2.NoIndex                     NaN
# 1883.2002.104.Crump.Artic.LTREB.main.lane1.NoIndex                     NaN
# 1883.2008.049.Crump.Artic.LTREB.main.lane2.NoIndex                     NaN
# 1883.2002.046.Crump.Artic.LTREB.main.lane1.NoIndex                     NaN
# 1883.2006.104.Crump.Artic.LTREB.main.lane1.NoIndex                     NaN
# 2080.S39D2585                                                          NaN
# 10180.G5I                                                              NaN
# 10245.40.Drnum4.day15.Bag10                                            NaN
#
#                                                    phosphate  \
# #SampleID
# 638.ELB15.111810.1                                      12.0
# 678.OA.mesocosm.433                                     1.28
# 723.C8.0m.G3.Catlin1.16Spool.110602.HWI.EAS137R...       0.8
# 755.LAB.IN.02.06.11.lane1.NoIndex.L001                 3.453
# 905.PLO6.t2.OX.0to1cm.3                                    5
# 1197.SE.20101011.GY.D064S.BC.245.a                       NaN
# 1222.B5.5.16.06                                         0.33
# 1240.1307T                                              0.03
# 1481.PO4.4.T0                                            NaN
# 1674.McG.F110714Ch2R5                                    NaN
# 1674.McG.G110718Ha6                                      NaN
# 1715.McG.NS2                                             NaN
# 1717.3.improved.leguminous                               NaN
# 1721.R15M                                                NaN
# 1721.S20B                                                NaN
# 1883.2011.139.Crump.Artic.LTREB.main.lane3.NoIndex       0.0
# 1883.2007.043.Crump.Artic.LTREB.main.lane1.NoIndex       NaN
# 1883.2010.224.Crump.Artic.LTREB.main.lane3.NoIndex       0.1
# 1883.2004.066.Crump.Artic.LTREB.main.lane1.NoIndex       0.0
# 1883.2009.259.Crump.Artic.LTREB.main.lane2.NoIndex       NaN
# 1883.2001.089.Crump.Artic.LTREB.main.lane1.NoIndex       0.1
# 1883.2008.37.Crump.Artic.LTREB.main.lane2.NoIndex        0.0
# 1883.2010.359.Crump.Artic.LTREB.main.lane3.NoIndex       0.1
# 1883.2004.028.Crump.Artic.LTREB.main.lane1.NoIndex       0.2
# 1883.2009.249.Crump.Artic.LTREB.main.lane2.NoIndex       0.1
# 1883.2002.104.Crump.Artic.LTREB.main.lane1.NoIndex       0.0
# 1883.2008.049.Crump.Artic.LTREB.main.lane2.NoIndex       NaN
# 1883.2002.046.Crump.Artic.LTREB.main.lane1.NoIndex       0.0
# 1883.2006.104.Crump.Artic.LTREB.main.lane1.NoIndex       NaN
# 2080.S39D2585                                           1.32
# 10180.G5I                                                NaN
# 10245.40.Drnum4.day15.Bag10                            250.0
#
#                                                    serum_tot_polyphenols  \
# #SampleID
# 638.ELB15.111810.1                                                   NaN
# 678.OA.mesocosm.433                                                  NaN
# 723.C8.0m.G3.Catlin1.16Spool.110602.HWI.EAS137R...                   NaN
# 755.LAB.IN.02.06.11.lane1.NoIndex.L001                               NaN
# 905.PLO6.t2.OX.0to1cm.3                                              NaN
# 1197.SE.20101011.GY.D064S.BC.245.a                                   NaN
# 1222.B5.5.16.06                                                      NaN
# 1240.1307T                                                           NaN
# 1481.PO4.4.T0                                                0.300388379
# 1674.McG.F110714Ch2R5                                                NaN
# 1674.McG.G110718Ha6                                                  NaN
# 1715.McG.NS2                                                         NaN
# 1717.3.improved.leguminous                                           NaN
# 1721.R15M                                                            NaN
# 1721.S20B                                                            NaN
# 1883.2011.139.Crump.Artic.LTREB.main.lane3.NoIndex                   NaN
# 1883.2007.043.Crump.Artic.LTREB.main.lane1.NoIndex                   NaN
# 1883.2010.224.Crump.Artic.LTREB.main.lane3.NoIndex                   NaN
# 1883.2004.066.Crump.Artic.LTREB.main.lane1.NoIndex                   NaN
# 1883.2009.259.Crump.Artic.LTREB.main.lane2.NoIndex                   NaN
# 1883.2001.089.Crump.Artic.LTREB.main.lane1.NoIndex                   NaN
# 1883.2008.37.Crump.Artic.LTREB.main.lane2.NoIndex                    NaN
# 1883.2010.359.Crump.Artic.LTREB.main.lane3.NoIndex                   NaN
# 1883.2004.028.Crump.Artic.LTREB.main.lane1.NoIndex                   NaN
# 1883.2009.249.Crump.Artic.LTREB.main.lane2.NoIndex                   NaN
# 1883.2002.104.Crump.Artic.LTREB.main.lane1.NoIndex                   NaN
# 1883.2008.049.Crump.Artic.LTREB.main.lane2.NoIndex                   NaN
# 1883.2002.046.Crump.Artic.LTREB.main.lane1.NoIndex                   NaN
# 1883.2006.104.Crump.Artic.LTREB.main.lane1.NoIndex                   NaN
# 2080.S39D2585                                                        NaN
# 10180.G5I                                                            NaN
# 10245.40.Drnum4.day15.Bag10                                          NaN
#
#                                                    tot_part_carb  \
# #SampleID
# 638.ELB15.111810.1                                           NaN
# 678.OA.mesocosm.433                                          NaN
# 723.C8.0m.G3.Catlin1.16Spool.110602.HWI.EAS137R...           NaN
# 755.LAB.IN.02.06.11.lane1.NoIndex.L001                       NaN
# 905.PLO6.t2.OX.0to1cm.3                                      NaN
# 1197.SE.20101011.GY.D064S.BC.245.a                           NaN
# 1222.B5.5.16.06                                              NaN
# 1240.1307T                                                   NaN
# 1481.PO4.4.T0                                                NaN
# 1674.McG.F110714Ch2R5                                        NaN
# 1674.McG.G110718Ha6                                          NaN
# 1715.McG.NS2                                                 NaN
# 1717.3.improved.leguminous                                   NaN
# 1721.R15M                                                    NaN
# 1721.S20B                                                    NaN
# 1883.2011.139.Crump.Artic.LTREB.main.lane3.NoIndex           NaN
# 1883.2007.043.Crump.Artic.LTREB.main.lane1.NoIndex           NaN
# 1883.2010.224.Crump.Artic.LTREB.main.lane3.NoIndex           NaN
# 1883.2004.066.Crump.Artic.LTREB.main.lane1.NoIndex           NaN
# 1883.2009.259.Crump.Artic.LTREB.main.lane2.NoIndex           NaN
# 1883.2001.089.Crump.Artic.LTREB.main.lane1.NoIndex           NaN
# 1883.2008.37.Crump.Artic.LTREB.main.lane2.NoIndex            NaN
# 1883.2010.359.Crump.Artic.LTREB.main.lane3.NoIndex           NaN
# 1883.2004.028.Crump.Artic.LTREB.main.lane1.NoIndex           NaN
# 1883.2009.249.Crump.Artic.LTREB.main.lane2.NoIndex           NaN
# 1883.2002.104.Crump.Artic.LTREB.main.lane1.NoIndex           NaN
# 1883.2008.049.Crump.Artic.LTREB.main.lane2.NoIndex           NaN
# 1883.2002.046.Crump.Artic.LTREB.main.lane1.NoIndex           NaN
# 1883.2006.104.Crump.Artic.LTREB.main.lane1.NoIndex           NaN
# 2080.S39D2585                                                NaN
# 10180.G5I                                                    NaN
# 10245.40.Drnum4.day15.Bag10                                  NaN
#
#                                                    feces_tot_polyphenols  \
# #SampleID
# 638.ELB15.111810.1                                                   NaN
# 678.OA.mesocosm.433                                                  NaN
# 723.C8.0m.G3.Catlin1.16Spool.110602.HWI.EAS137R...                   NaN
# 755.LAB.IN.02.06.11.lane1.NoIndex.L001                               NaN
# 905.PLO6.t2.OX.0to1cm.3                                              NaN
# 1197.SE.20101011.GY.D064S.BC.245.a                                   NaN
# 1222.B5.5.16.06                                                      NaN
# 1240.1307T                                                           NaN
# 1481.PO4.4.T0                                                14769.70175
# 1674.McG.F110714Ch2R5                                                NaN
# 1674.McG.G110718Ha6                                                  NaN
# 1715.McG.NS2                                                         NaN
# 1717.3.improved.leguminous                                           NaN
# 1721.R15M                                                            NaN
# 1721.S20B                                                            NaN
# 1883.2011.139.Crump.Artic.LTREB.main.lane3.NoIndex                   NaN
# 1883.2007.043.Crump.Artic.LTREB.main.lane1.NoIndex                   NaN
# 1883.2010.224.Crump.Artic.LTREB.main.lane3.NoIndex                   NaN
# 1883.2004.066.Crump.Artic.LTREB.main.lane1.NoIndex                   NaN
# 1883.2009.259.Crump.Artic.LTREB.main.lane2.NoIndex                   NaN
# 1883.2001.089.Crump.Artic.LTREB.main.lane1.NoIndex                   NaN
# 1883.2008.37.Crump.Artic.LTREB.main.lane2.NoIndex                    NaN
# 1883.2010.359.Crump.Artic.LTREB.main.lane3.NoIndex                   NaN
# 1883.2004.028.Crump.Artic.LTREB.main.lane1.NoIndex                   NaN
# 1883.2009.249.Crump.Artic.LTREB.main.lane2.NoIndex                   NaN
# 1883.2002.104.Crump.Artic.LTREB.main.lane1.NoIndex                   NaN
# 1883.2008.049.Crump.Artic.LTREB.main.lane2.NoIndex                   NaN
# 1883.2002.046.Crump.Artic.LTREB.main.lane1.NoIndex                   NaN
# 1883.2006.104.Crump.Artic.LTREB.main.lane1.NoIndex                   NaN
# 2080.S39D2585                                                        NaN
# 10180.G5I                                                            NaN
# 10245.40.Drnum4.day15.Bag10                                          NaN
#
#                                                    ppm_p tot_phos  \
# #SampleID
# 638.ELB15.111810.1                                   NaN      NaN
# 678.OA.mesocosm.433                                  NaN      NaN
# 723.C8.0m.G3.Catlin1.16Spool.110602.HWI.EAS137R...   NaN      NaN
# 755.LAB.IN.02.06.11.lane1.NoIndex.L001               NaN      NaN
# 905.PLO6.t2.OX.0to1cm.3                              NaN      NaN
# 1197.SE.20101011.GY.D064S.BC.245.a                   NaN      NaN
# 1222.B5.5.16.06                                      NaN      NaN
# 1240.1307T                                           NaN      NaN
# 1481.PO4.4.T0                                        NaN      NaN
# 1674.McG.F110714Ch2R5                                NaN      NaN
# 1674.McG.G110718Ha6                                  NaN      NaN
# 1715.McG.NS2                                           5      NaN
# 1717.3.improved.leguminous                           NaN       14
# 1721.R15M                                            NaN      NaN
# 1721.S20B                                            NaN      NaN
# 1883.2011.139.Crump.Artic.LTREB.main.lane3.NoIndex   NaN      NaN
# 1883.2007.043.Crump.Artic.LTREB.main.lane1.NoIndex   NaN      NaN
# 1883.2010.224.Crump.Artic.LTREB.main.lane3.NoIndex   NaN      NaN
# 1883.2004.066.Crump.Artic.LTREB.main.lane1.NoIndex   NaN      NaN
# 1883.2009.259.Crump.Artic.LTREB.main.lane2.NoIndex   NaN      NaN
# 1883.2001.089.Crump.Artic.LTREB.main.lane1.NoIndex   NaN      NaN
# 1883.2008.37.Crump.Artic.LTREB.main.lane2.NoIndex    NaN      NaN
# 1883.2010.359.Crump.Artic.LTREB.main.lane3.NoIndex   NaN      NaN
# 1883.2004.028.Crump.Artic.LTREB.main.lane1.NoIndex   NaN      NaN
# 1883.2009.249.Crump.Artic.LTREB.main.lane2.NoIndex   NaN      NaN
# 1883.2002.104.Crump.Artic.LTREB.main.lane1.NoIndex   NaN      NaN
# 1883.2008.049.Crump.Artic.LTREB.main.lane2.NoIndex   NaN      NaN
# 1883.2002.046.Crump.Artic.LTREB.main.lane1.NoIndex   NaN      NaN
# 1883.2006.104.Crump.Artic.LTREB.main.lane1.NoIndex   NaN      NaN
# 2080.S39D2585                                        NaN      NaN
# 10180.G5I                                            NaN      NaN
# 10245.40.Drnum4.day15.Bag10                          NaN      NaN
#
#                                                    phosphate_range  \
# #SampleID
# 638.ELB15.111810.1                                             NaN
# 678.OA.mesocosm.433                                            NaN
# 723.C8.0m.G3.Catlin1.16Spool.110602.HWI.EAS137R...             NaN
# 755.LAB.IN.02.06.11.lane1.NoIndex.L001                         NaN
# 905.PLO6.t2.OX.0to1cm.3                                        NaN
# 1197.SE.20101011.GY.D064S.BC.245.a                             NaN
# 1222.B5.5.16.06                                                NaN
# 1240.1307T                                                     NaN
# 1481.PO4.4.T0                                                  NaN
# 1674.McG.F110714Ch2R5                                          NaN
# 1674.McG.G110718Ha6                                            NaN
# 1715.McG.NS2                                                   NaN
# 1717.3.improved.leguminous                                     NaN
# 1721.R15M                                                      NaN
# 1721.S20B                                                      NaN
# 1883.2011.139.Crump.Artic.LTREB.main.lane3.NoIndex             NaN
# 1883.2007.043.Crump.Artic.LTREB.main.lane1.NoIndex             NaN
# 1883.2010.224.Crump.Artic.LTREB.main.lane3.NoIndex             NaN
# 1883.2004.066.Crump.Artic.LTREB.main.lane1.NoIndex             NaN
# 1883.2009.259.Crump.Artic.LTREB.main.lane2.NoIndex             NaN
# 1883.2001.089.Crump.Artic.LTREB.main.lane1.NoIndex             NaN
# 1883.2008.37.Crump.Artic.LTREB.main.lane2.NoIndex              NaN
# 1883.2010.359.Crump.Artic.LTREB.main.lane3.NoIndex             NaN
# 1883.2004.028.Crump.Artic.LTREB.main.lane1.NoIndex             NaN
# 1883.2009.249.Crump.Artic.LTREB.main.lane2.NoIndex             NaN
# 1883.2002.104.Crump.Artic.LTREB.main.lane1.NoIndex             NaN
# 1883.2008.049.Crump.Artic.LTREB.main.lane2.NoIndex             NaN
# 1883.2002.046.Crump.Artic.LTREB.main.lane1.NoIndex             NaN
# 1883.2006.104.Crump.Artic.LTREB.main.lane1.NoIndex             NaN
# 2080.S39D2585                                                 1.32
# 10180.G5I                                                      NaN
# 10245.40.Drnum4.day15.Bag10                                    NaN
#
#                                                    diss_inorg_phosph  \
# #SampleID
# 638.ELB15.111810.1                                               NaN
# 678.OA.mesocosm.433                                              NaN
# 723.C8.0m.G3.Catlin1.16Spool.110602.HWI.EAS137R...               NaN
# 755.LAB.IN.02.06.11.lane1.NoIndex.L001                           NaN
# 905.PLO6.t2.OX.0to1cm.3                                          NaN
# 1197.SE.20101011.GY.D064S.BC.245.a                               NaN
# 1222.B5.5.16.06                                                  NaN
# 1240.1307T                                                       NaN
# 1481.PO4.4.T0                                                    NaN
# 1674.McG.F110714Ch2R5                                        449.844
# 1674.McG.G110718Ha6                                          329.486
# 1715.McG.NS2                                                     NaN
# 1717.3.improved.leguminous                                       NaN
# 1721.R15M                                                        NaN
# 1721.S20B                                                        NaN
# 1883.2011.139.Crump.Artic.LTREB.main.lane3.NoIndex               NaN
# 1883.2007.043.Crump.Artic.LTREB.main.lane1.NoIndex               NaN
# 1883.2010.224.Crump.Artic.LTREB.main.lane3.NoIndex               NaN
# 1883.2004.066.Crump.Artic.LTREB.main.lane1.NoIndex               NaN
# 1883.2009.259.Crump.Artic.LTREB.main.lane2.NoIndex               NaN
# 1883.2001.089.Crump.Artic.LTREB.main.lane1.NoIndex               NaN
# 1883.2008.37.Crump.Artic.LTREB.main.lane2.NoIndex                NaN
# 1883.2010.359.Crump.Artic.LTREB.main.lane3.NoIndex               NaN
# 1883.2004.028.Crump.Artic.LTREB.main.lane1.NoIndex               NaN
# 1883.2009.249.Crump.Artic.LTREB.main.lane2.NoIndex               NaN
# 1883.2002.104.Crump.Artic.LTREB.main.lane1.NoIndex               NaN
# 1883.2008.049.Crump.Artic.LTREB.main.lane2.NoIndex               NaN
# 1883.2002.046.Crump.Artic.LTREB.main.lane1.NoIndex               NaN
# 1883.2006.104.Crump.Artic.LTREB.main.lane1.NoIndex               NaN
# 2080.S39D2585                                                    NaN
# 10180.G5I                                                        NaN
# 10245.40.Drnum4.day15.Bag10                                      NaN
#
#                                                    phosphorus diss_phosphate
# #SampleID
# 638.ELB15.111810.1                                        NaN            NaN
# 678.OA.mesocosm.433                                       NaN            NaN
# 723.C8.0m.G3.Catlin1.16Spool.110602.HWI.EAS137R...        NaN            NaN
# 755.LAB.IN.02.06.11.lane1.NoIndex.L001                    NaN            NaN
# 905.PLO6.t2.OX.0to1cm.3                                   NaN            NaN
# 1197.SE.20101011.GY.D064S.BC.245.a                        NaN             75
# 1222.B5.5.16.06                                           NaN            NaN
# 1240.1307T                                                NaN            NaN
# 1481.PO4.4.T0                                             NaN            NaN
# 1674.McG.F110714Ch2R5                                     NaN            NaN
# 1674.McG.G110718Ha6                                       NaN            NaN
# 1715.McG.NS2                                              NaN            NaN
# 1717.3.improved.leguminous                                NaN            NaN
# 1721.R15M                                                 NaN            NaN
# 1721.S20B                                                 NaN            NaN
# 1883.2011.139.Crump.Artic.LTREB.main.lane3.NoIndex        NaN            NaN
# 1883.2007.043.Crump.Artic.LTREB.main.lane1.NoIndex        NaN            NaN
# 1883.2010.224.Crump.Artic.LTREB.main.lane3.NoIndex        NaN            NaN
# 1883.2004.066.Crump.Artic.LTREB.main.lane1.NoIndex        NaN            NaN
# 1883.2009.259.Crump.Artic.LTREB.main.lane2.NoIndex        NaN            NaN
# 1883.2001.089.Crump.Artic.LTREB.main.lane1.NoIndex        NaN            NaN
# 1883.2008.37.Crump.Artic.LTREB.main.lane2.NoIndex         NaN            NaN
# 1883.2010.359.Crump.Artic.LTREB.main.lane3.NoIndex        NaN            NaN
# 1883.2004.028.Crump.Artic.LTREB.main.lane1.NoIndex        NaN            NaN
# 1883.2009.249.Crump.Artic.LTREB.main.lane2.NoIndex        NaN            NaN
# 1883.2002.104.Crump.Artic.LTREB.main.lane1.NoIndex        NaN            NaN
# 1883.2008.049.Crump.Artic.LTREB.main.lane2.NoIndex        NaN            NaN
# 1883.2002.046.Crump.Artic.LTREB.main.lane1.NoIndex        NaN            NaN
# 1883.2006.104.Crump.Artic.LTREB.main.lane1.NoIndex        NaN            NaN
# 2080.S39D2585                                             NaN            NaN
# 10180.G5I                                                76.0            NaN
# 10245.40.Drnum4.day15.Bag10                             0.085            NaN

# %%
# nitrogen -- don't know units!
nitr_variants = []
for header in header_counts_keys:
    if re.search(r'nitr|tot_n|ppm_n|ammon|urea', header, re.IGNORECASE):
        nitr_variants.append(header)
df_nitr = df_merged[nitr_variants].dropna(how='all')
df_nitr.iloc[np.arange(0, df_nitr.shape[0], 100)]
# Out:
#                                                    nitro_org_carb_unit  \
# #SampleID
# 632.Agricultural.soil.soy                                          NaN
# 678.OA.mesocosm.405                                                NaN
# 723.C6.3m.L3.Catlin1.16Spool.110602.HWI.EAS137R...                 NaN
# 755.EFA.12.07.11.lane1.NoIndex.L001                                NaN
# 864.12.OTC.addV.noG.noW.lane2.NoIndex                              NaN
# 864.5.CON.addV.noG.noW.A.lane2.NoIndex                             NaN
# 889.25May.4                                                        NaN
# 990.KA3U.B.13                                                      NaN
# 990.KA2U.B.20                                                      NaN
# 990.KA1F.B.09                                                      NaN
# 990.KA2U.D.24                                                      NaN
# 990.KA3U.A.11                                                      NaN
# 990.KA2U.B.12                                                      NaN
# 990.KA1F.D.16                                                      NaN
# 1024.RU006.C181.RH.5.596.bulk.4.12.G1.L00                          NaN
# 1031.HJDF3                                                         NaN
# 1041.M028.10                                                       NaN
# 1197.SE.20101009.GY.D019S.BC.217                                   NaN
# 1222.B5.5.7.06                                                     NaN
# 1240.1210T                                                         NaN
# 1521.SK1.s.6.1.sequences                                           NaN
# 1627.DRBC                                                          NaN
# 1674.McG.F110715Ly6R3                                              NaN
# 1713.McG.L3B1020                                                   NaN
# 1715.McG.NE1                                                       NaN
# 1717.21.improved.leguminous                                        NaN
# 1721.R15M                                                          NaN
# 1721.S1B                                                           NaN
# 1721.BMC.7.5T.21.3                                                 NaN
# 1883.2010.026.Crump.Artic.LTREB.main.lane3.NoIndex                 NaN
# 1883.2008.072.Crump.Artic.LTREB.main.lane2.NoIndex                 NaN
# 1883.2007.359.Crump.Artic.LTREB.main.lane2.NoIndex                 NaN
# 1883.2001.099.Crump.Artic.LTREB.main.lane1.NoIndex                 NaN
# 1883.2010.268.Crump.Artic.LTREB.main.lane3.NoIndex                 NaN
# 1883.2008.222.Crump.Artic.LTREB.main.lane2.NoIndex                 NaN
# 1883.2004.208.Crump.Artic.LTREB.main.lane1.NoIndex                 NaN
# 1883.2002.171.Crump.Artic.LTREB.main.lane1.NoIndex                 NaN
# 1883.2010.273.Crump.Artic.LTREB.main.lane3.NoIndex                 NaN
# 1883.2008.575.Crump.Artic.LTREB.main.lane4.NoIndex                 NaN
# 1883.2006.182.Crump.Artic.LTREB.main.lane1.NoIndex                 NaN
# 1883.2005.187.Crump.Artic.LTREB.main.lane4.NoIndex                 NaN
# 1883.2011.188.Crump.Artic.LTREB.main.lane3.NoIndex                 NaN
# 1883.2009.117.Crump.Artic.LTREB.main.lane3.NoIndex                 NaN
# 1883.2007.515.Crump.Artic.LTREB.main.lane2.NoIndex                 NaN
# 1883.2004.132.Crump.Artic.LTREB.main.lane1.NoIndex                 NaN
# 1883.2011.488.Crump.Artic.LTREB.main.lane4.NoIndex                 NaN
# 1883.2010.347.Crump.Artic.LTREB.main.lane3.NoIndex                 NaN
# 1883.2008.501.Crump.Artic.LTREB.main.lane3.NoIndex                 NaN
# 1883.2004.137.Crump.Artic.LTREB.main.lane1.NoIndex                 NaN
# 1883.2011.41.Crump.Artic.LTREB.main.lane4.NoIndex                  NaN
# 1883.2010.323A.Crump.Artic.LTREB.main.lane3.NoI...                 NaN
# 1883.2008.527.Crump.Artic.LTREB.main.lane3.NoIndex                 NaN
# 1883.2004.121.Crump.Artic.LTREB.main.lane1.NoIndex                 NaN
# 1883.2011.538.Crump.Artic.LTREB.main.lane3.NoIndex                 NaN
# 1883.2009.374.Crump.Artic.LTREB.main.lane3.NoIndex                 NaN
# 1883.2008.038.Crump.Artic.LTREB.main.lane2.NoIndex                 NaN
# 1883.2007.116.Crump.Artic.LTREB.main.lane2.NoIndex                 NaN
# 1883.2007.278.Crump.Artic.LTREB.main.lane2.NoIndex                 NaN
# 1883.2010.164.Crump.Artic.LTREB.main.lane3.NoIndex                 NaN
# 1883.2008.04.Crump.Artic.LTREB.main.lane2.NoIndex                  NaN
# 1883.2007.341.Crump.Artic.LTREB.main.lane2.NoIndex                 NaN
# 1883.2007.31.Crump.Artic.LTREB.main.lane2.NoIndex                  NaN
# 2382.SH004.C1.RH.5.421.bulk.4.12.lane7.NoIndex....                 NaN
# 10156.1S4                                                          NaN
# 10156.N1.2                                                         NaN
# 10245.68.Drnum7.day36.Bag8                                         NaN
# 10246.PP.B11                                                       NaN
# 10246.L.I5                                                         NaN
#
#                                                            tot_nitro_unit  \
# #SampleID
# 632.Agricultural.soil.soy                                             NaN
# 678.OA.mesocosm.405                                                   NaN
# 723.C6.3m.L3.Catlin1.16Spool.110602.HWI.EAS137R...                    NaN
# 755.EFA.12.07.11.lane1.NoIndex.L001                                   NaN
# 864.12.OTC.addV.noG.noW.lane2.NoIndex                                 NaN
# 864.5.CON.addV.noG.noW.A.lane2.NoIndex                                NaN
# 889.25May.4                                                           NaN
# 990.KA3U.B.13                                                         NaN
# 990.KA2U.B.20                                                         NaN
# 990.KA1F.B.09                                                         NaN
# 990.KA2U.D.24                                                         NaN
# 990.KA3U.A.11                                                         NaN
# 990.KA2U.B.12                                                         NaN
# 990.KA1F.D.16                                                         NaN
# 1024.RU006.C181.RH.5.596.bulk.4.12.G1.L00                             NaN
# 1031.HJDF3                                          grams nitrogen per kg
# 1041.M028.10                                                          NaN
# 1197.SE.20101009.GY.D019S.BC.217                                      NaN
# 1222.B5.5.7.06                                                        NaN
# 1240.1210T                                                            NaN
# 1521.SK1.s.6.1.sequences                                              NaN
# 1627.DRBC                                                             NaN
# 1674.McG.F110715Ly6R3                                                 NaN
# 1713.McG.L3B1020                                                      NaN
# 1715.McG.NE1                                                          NaN
# 1717.21.improved.leguminous                                           NaN
# 1721.R15M                                                             NaN
# 1721.S1B                                                              NaN
# 1721.BMC.7.5T.21.3                                                    NaN
# 1883.2010.026.Crump.Artic.LTREB.main.lane3.NoIndex                    NaN
# 1883.2008.072.Crump.Artic.LTREB.main.lane2.NoIndex                    NaN
# 1883.2007.359.Crump.Artic.LTREB.main.lane2.NoIndex                    NaN
# 1883.2001.099.Crump.Artic.LTREB.main.lane1.NoIndex                    NaN
# 1883.2010.268.Crump.Artic.LTREB.main.lane3.NoIndex                    NaN
# 1883.2008.222.Crump.Artic.LTREB.main.lane2.NoIndex                    NaN
# 1883.2004.208.Crump.Artic.LTREB.main.lane1.NoIndex                    NaN
# 1883.2002.171.Crump.Artic.LTREB.main.lane1.NoIndex                    NaN
# 1883.2010.273.Crump.Artic.LTREB.main.lane3.NoIndex                    NaN
# 1883.2008.575.Crump.Artic.LTREB.main.lane4.NoIndex                    NaN
# 1883.2006.182.Crump.Artic.LTREB.main.lane1.NoIndex                    NaN
# 1883.2005.187.Crump.Artic.LTREB.main.lane4.NoIndex                    NaN
# 1883.2011.188.Crump.Artic.LTREB.main.lane3.NoIndex                    NaN
# 1883.2009.117.Crump.Artic.LTREB.main.lane3.NoIndex                    NaN
# 1883.2007.515.Crump.Artic.LTREB.main.lane2.NoIndex                    NaN
# 1883.2004.132.Crump.Artic.LTREB.main.lane1.NoIndex                    NaN
# 1883.2011.488.Crump.Artic.LTREB.main.lane4.NoIndex                    NaN
# 1883.2010.347.Crump.Artic.LTREB.main.lane3.NoIndex                    NaN
# 1883.2008.501.Crump.Artic.LTREB.main.lane3.NoIndex                    NaN
# 1883.2004.137.Crump.Artic.LTREB.main.lane1.NoIndex                    NaN
# 1883.2011.41.Crump.Artic.LTREB.main.lane4.NoIndex                     NaN
# 1883.2010.323A.Crump.Artic.LTREB.main.lane3.NoI...                    NaN
# 1883.2008.527.Crump.Artic.LTREB.main.lane3.NoIndex                    NaN
# 1883.2004.121.Crump.Artic.LTREB.main.lane1.NoIndex                    NaN
# 1883.2011.538.Crump.Artic.LTREB.main.lane3.NoIndex                    NaN
# 1883.2009.374.Crump.Artic.LTREB.main.lane3.NoIndex                    NaN
# 1883.2008.038.Crump.Artic.LTREB.main.lane2.NoIndex                    NaN
# 1883.2007.116.Crump.Artic.LTREB.main.lane2.NoIndex                    NaN
# 1883.2007.278.Crump.Artic.LTREB.main.lane2.NoIndex                    NaN
# 1883.2010.164.Crump.Artic.LTREB.main.lane3.NoIndex                    NaN
# 1883.2008.04.Crump.Artic.LTREB.main.lane2.NoIndex                     NaN
# 1883.2007.341.Crump.Artic.LTREB.main.lane2.NoIndex                    NaN
# 1883.2007.31.Crump.Artic.LTREB.main.lane2.NoIndex                     NaN
# 2382.SH004.C1.RH.5.421.bulk.4.12.lane7.NoIndex....                    NaN
# 10156.1S4                                                             NaN
# 10156.N1.2                                                            NaN
# 10245.68.Drnum7.day36.Bag8                                            NaN
# 10246.PP.B11                                                          NaN
# 10246.L.I5                                                            NaN
#
#                                                    nitrite nitrogen_perc  \
# #SampleID
# 632.Agricultural.soil.soy                              NaN           NaN
# 678.OA.mesocosm.405                                    NaN           NaN
# 723.C6.3m.L3.Catlin1.16Spool.110602.HWI.EAS137R...    0.89           NaN
# 755.EFA.12.07.11.lane1.NoIndex.L001                    0.0           NaN
# 864.12.OTC.addV.noG.noW.lane2.NoIndex                  NaN           NaN
# 864.5.CON.addV.noG.noW.A.lane2.NoIndex                 NaN           NaN
# 889.25May.4                                         0.0086           NaN
# 990.KA3U.B.13                                          NaN           NaN
# 990.KA2U.B.20                                          NaN           NaN
# 990.KA1F.B.09                                          NaN           NaN
# 990.KA2U.D.24                                          NaN           NaN
# 990.KA3U.A.11                                          NaN           NaN
# 990.KA2U.B.12                                          NaN           NaN
# 990.KA1F.D.16                                          NaN           NaN
# 1024.RU006.C181.RH.5.596.bulk.4.12.G1.L00              NaN         0.078
# 1031.HJDF3                                             NaN           NaN
# 1041.M028.10                                           NaN           NaN
# 1197.SE.20101009.GY.D019S.BC.217                       NaN           NaN
# 1222.B5.5.7.06                                         NaN           NaN
# 1240.1210T                                            0.67           NaN
# 1521.SK1.s.6.1.sequences                               NaN           NaN
# 1627.DRBC                                              NaN           NaN
# 1674.McG.F110715Ly6R3                                  NaN           NaN
# 1713.McG.L3B1020                                       NaN           NaN
# 1715.McG.NE1                                           NaN           NaN
# 1717.21.improved.leguminous                            NaN           NaN
# 1721.R15M                                              NaN           NaN
# 1721.S1B                                               NaN           NaN
# 1721.BMC.7.5T.21.3                                     NaN           NaN
# 1883.2010.026.Crump.Artic.LTREB.main.lane3.NoIndex     NaN           NaN
# 1883.2008.072.Crump.Artic.LTREB.main.lane2.NoIndex     NaN           NaN
# 1883.2007.359.Crump.Artic.LTREB.main.lane2.NoIndex     NaN           NaN
# 1883.2001.099.Crump.Artic.LTREB.main.lane1.NoIndex     NaN           NaN
# 1883.2010.268.Crump.Artic.LTREB.main.lane3.NoIndex     NaN           NaN
# 1883.2008.222.Crump.Artic.LTREB.main.lane2.NoIndex     NaN           NaN
# 1883.2004.208.Crump.Artic.LTREB.main.lane1.NoIndex     NaN           NaN
# 1883.2002.171.Crump.Artic.LTREB.main.lane1.NoIndex     NaN           NaN
# 1883.2010.273.Crump.Artic.LTREB.main.lane3.NoIndex     NaN           NaN
# 1883.2008.575.Crump.Artic.LTREB.main.lane4.NoIndex     NaN           NaN
# 1883.2006.182.Crump.Artic.LTREB.main.lane1.NoIndex     NaN           NaN
# 1883.2005.187.Crump.Artic.LTREB.main.lane4.NoIndex     NaN           NaN
# 1883.2011.188.Crump.Artic.LTREB.main.lane3.NoIndex     NaN           NaN
# 1883.2009.117.Crump.Artic.LTREB.main.lane3.NoIndex     NaN           NaN
# 1883.2007.515.Crump.Artic.LTREB.main.lane2.NoIndex     NaN           NaN
# 1883.2004.132.Crump.Artic.LTREB.main.lane1.NoIndex     NaN           NaN
# 1883.2011.488.Crump.Artic.LTREB.main.lane4.NoIndex     NaN           NaN
# 1883.2010.347.Crump.Artic.LTREB.main.lane3.NoIndex     NaN           NaN
# 1883.2008.501.Crump.Artic.LTREB.main.lane3.NoIndex     NaN           NaN
# 1883.2004.137.Crump.Artic.LTREB.main.lane1.NoIndex     NaN           NaN
# 1883.2011.41.Crump.Artic.LTREB.main.lane4.NoIndex      NaN           NaN
# 1883.2010.323A.Crump.Artic.LTREB.main.lane3.NoI...     NaN           NaN
# 1883.2008.527.Crump.Artic.LTREB.main.lane3.NoIndex     NaN           NaN
# 1883.2004.121.Crump.Artic.LTREB.main.lane1.NoIndex     NaN           NaN
# 1883.2011.538.Crump.Artic.LTREB.main.lane3.NoIndex     NaN           NaN
# 1883.2009.374.Crump.Artic.LTREB.main.lane3.NoIndex     NaN           NaN
# 1883.2008.038.Crump.Artic.LTREB.main.lane2.NoIndex     NaN           NaN
# 1883.2007.116.Crump.Artic.LTREB.main.lane2.NoIndex     NaN           NaN
# 1883.2007.278.Crump.Artic.LTREB.main.lane2.NoIndex     NaN           NaN
# 1883.2010.164.Crump.Artic.LTREB.main.lane3.NoIndex     NaN           NaN
# 1883.2008.04.Crump.Artic.LTREB.main.lane2.NoIndex      NaN           NaN
# 1883.2007.341.Crump.Artic.LTREB.main.lane2.NoIndex     NaN           NaN
# 1883.2007.31.Crump.Artic.LTREB.main.lane2.NoIndex      NaN           NaN
# 2382.SH004.C1.RH.5.421.bulk.4.12.lane7.NoIndex....     NaN         0.182
# 10156.1S4                                              NaN           NaN
# 10156.N1.2                                             NaN           NaN
# 10245.68.Drnum7.day36.Bag8                             NaN           NaN
# 10246.PP.B11                                           NaN           NaN
# 10246.L.I5                                             NaN           NaN
#
#                                                    carb_nitro_ratio  \
# #SampleID
# 632.Agricultural.soil.soy                                       NaN
# 678.OA.mesocosm.405                                             NaN
# 723.C6.3m.L3.Catlin1.16Spool.110602.HWI.EAS137R...              NaN
# 755.EFA.12.07.11.lane1.NoIndex.L001                             NaN
# 864.12.OTC.addV.noG.noW.lane2.NoIndex                           NaN
# 864.5.CON.addV.noG.noW.A.lane2.NoIndex                          NaN
# 889.25May.4                                                     NaN
# 990.KA3U.B.13                                                   NaN
# 990.KA2U.B.20                                                   NaN
# 990.KA1F.B.09                                                   NaN
# 990.KA2U.D.24                                                   NaN
# 990.KA3U.A.11                                                   NaN
# 990.KA2U.B.12                                                   NaN
# 990.KA1F.D.16                                                   NaN
# 1024.RU006.C181.RH.5.596.bulk.4.12.G1.L00                       NaN
# 1031.HJDF3                                                      NaN
# 1041.M028.10                                                    NaN
# 1197.SE.20101009.GY.D019S.BC.217                                NaN
# 1222.B5.5.7.06                                                  NaN
# 1240.1210T                                                      NaN
# 1521.SK1.s.6.1.sequences                                    31.6767
# 1627.DRBC                                                      24.2
# 1674.McG.F110715Ly6R3                                           NaN
# 1713.McG.L3B1020                                                NaN
# 1715.McG.NE1                                                    NaN
# 1717.21.improved.leguminous                                     NaN
# 1721.R15M                                                       NaN
# 1721.S1B                                                        NaN
# 1721.BMC.7.5T.21.3                                              NaN
# 1883.2010.026.Crump.Artic.LTREB.main.lane3.NoIndex              NaN
# 1883.2008.072.Crump.Artic.LTREB.main.lane2.NoIndex              NaN
# 1883.2007.359.Crump.Artic.LTREB.main.lane2.NoIndex              NaN
# 1883.2001.099.Crump.Artic.LTREB.main.lane1.NoIndex              NaN
# 1883.2010.268.Crump.Artic.LTREB.main.lane3.NoIndex              NaN
# 1883.2008.222.Crump.Artic.LTREB.main.lane2.NoIndex              NaN
# 1883.2004.208.Crump.Artic.LTREB.main.lane1.NoIndex              NaN
# 1883.2002.171.Crump.Artic.LTREB.main.lane1.NoIndex              NaN
# 1883.2010.273.Crump.Artic.LTREB.main.lane3.NoIndex              NaN
# 1883.2008.575.Crump.Artic.LTREB.main.lane4.NoIndex              NaN
# 1883.2006.182.Crump.Artic.LTREB.main.lane1.NoIndex              NaN
# 1883.2005.187.Crump.Artic.LTREB.main.lane4.NoIndex              NaN
# 1883.2011.188.Crump.Artic.LTREB.main.lane3.NoIndex              NaN
# 1883.2009.117.Crump.Artic.LTREB.main.lane3.NoIndex              NaN
# 1883.2007.515.Crump.Artic.LTREB.main.lane2.NoIndex              NaN
# 1883.2004.132.Crump.Artic.LTREB.main.lane1.NoIndex              NaN
# 1883.2011.488.Crump.Artic.LTREB.main.lane4.NoIndex              NaN
# 1883.2010.347.Crump.Artic.LTREB.main.lane3.NoIndex              NaN
# 1883.2008.501.Crump.Artic.LTREB.main.lane3.NoIndex              NaN
# 1883.2004.137.Crump.Artic.LTREB.main.lane1.NoIndex              NaN
# 1883.2011.41.Crump.Artic.LTREB.main.lane4.NoIndex               NaN
# 1883.2010.323A.Crump.Artic.LTREB.main.lane3.NoI...              NaN
# 1883.2008.527.Crump.Artic.LTREB.main.lane3.NoIndex              NaN
# 1883.2004.121.Crump.Artic.LTREB.main.lane1.NoIndex              NaN
# 1883.2011.538.Crump.Artic.LTREB.main.lane3.NoIndex              NaN
# 1883.2009.374.Crump.Artic.LTREB.main.lane3.NoIndex              NaN
# 1883.2008.038.Crump.Artic.LTREB.main.lane2.NoIndex              NaN
# 1883.2007.116.Crump.Artic.LTREB.main.lane2.NoIndex              NaN
# 1883.2007.278.Crump.Artic.LTREB.main.lane2.NoIndex              NaN
# 1883.2010.164.Crump.Artic.LTREB.main.lane3.NoIndex              NaN
# 1883.2008.04.Crump.Artic.LTREB.main.lane2.NoIndex               NaN
# 1883.2007.341.Crump.Artic.LTREB.main.lane2.NoIndex              NaN
# 1883.2007.31.Crump.Artic.LTREB.main.lane2.NoIndex               NaN
# 2382.SH004.C1.RH.5.421.bulk.4.12.lane7.NoIndex....              NaN
# 10156.1S4                                                       NaN
# 10156.N1.2                                                      NaN
# 10245.68.Drnum7.day36.Bag8                                      NaN
# 10246.PP.B11                                                   18.4
# 10246.L.I5                                                     34.6
#
#                                                    tephroseris_atropurpurea  \
# #SampleID
# 632.Agricultural.soil.soy                                               NaN
# 678.OA.mesocosm.405                                                     NaN
# 723.C6.3m.L3.Catlin1.16Spool.110602.HWI.EAS137R...                      NaN
# 755.EFA.12.07.11.lane1.NoIndex.L001                                     NaN
# 864.12.OTC.addV.noG.noW.lane2.NoIndex                                   NaN
# 864.5.CON.addV.noG.noW.A.lane2.NoIndex                                  NaN
# 889.25May.4                                                             NaN
# 990.KA3U.B.13                                                           NaN
# 990.KA2U.B.20                                                           NaN
# 990.KA1F.B.09                                                           NaN
# 990.KA2U.D.24                                                           NaN
# 990.KA3U.A.11                                                           NaN
# 990.KA2U.B.12                                                           NaN
# 990.KA1F.D.16                                                           NaN
# 1024.RU006.C181.RH.5.596.bulk.4.12.G1.L00                               NaN
# 1031.HJDF3                                                              NaN
# 1041.M028.10                                                            NaN
# 1197.SE.20101009.GY.D019S.BC.217                                        NaN
# 1222.B5.5.7.06                                                          NaN
# 1240.1210T                                                              NaN
# 1521.SK1.s.6.1.sequences                                                NaN
# 1627.DRBC                                                               NaN
# 1674.McG.F110715Ly6R3                                                   NaN
# 1713.McG.L3B1020                                                        NaN
# 1715.McG.NE1                                                            NaN
# 1717.21.improved.leguminous                                             NaN
# 1721.R15M                                                               NaN
# 1721.S1B                                                                NaN
# 1721.BMC.7.5T.21.3                                                      NaN
# 1883.2010.026.Crump.Artic.LTREB.main.lane3.NoIndex                      NaN
# 1883.2008.072.Crump.Artic.LTREB.main.lane2.NoIndex                      NaN
# 1883.2007.359.Crump.Artic.LTREB.main.lane2.NoIndex                      NaN
# 1883.2001.099.Crump.Artic.LTREB.main.lane1.NoIndex                      NaN
# 1883.2010.268.Crump.Artic.LTREB.main.lane3.NoIndex                      NaN
# 1883.2008.222.Crump.Artic.LTREB.main.lane2.NoIndex                      NaN
# 1883.2004.208.Crump.Artic.LTREB.main.lane1.NoIndex                      NaN
# 1883.2002.171.Crump.Artic.LTREB.main.lane1.NoIndex                      NaN
# 1883.2010.273.Crump.Artic.LTREB.main.lane3.NoIndex                      NaN
# 1883.2008.575.Crump.Artic.LTREB.main.lane4.NoIndex                      NaN
# 1883.2006.182.Crump.Artic.LTREB.main.lane1.NoIndex                      NaN
# 1883.2005.187.Crump.Artic.LTREB.main.lane4.NoIndex                      NaN
# 1883.2011.188.Crump.Artic.LTREB.main.lane3.NoIndex                      NaN
# 1883.2009.117.Crump.Artic.LTREB.main.lane3.NoIndex                      NaN
# 1883.2007.515.Crump.Artic.LTREB.main.lane2.NoIndex                      NaN
# 1883.2004.132.Crump.Artic.LTREB.main.lane1.NoIndex                      NaN
# 1883.2011.488.Crump.Artic.LTREB.main.lane4.NoIndex                      NaN
# 1883.2010.347.Crump.Artic.LTREB.main.lane3.NoIndex                      NaN
# 1883.2008.501.Crump.Artic.LTREB.main.lane3.NoIndex                      NaN
# 1883.2004.137.Crump.Artic.LTREB.main.lane1.NoIndex                      NaN
# 1883.2011.41.Crump.Artic.LTREB.main.lane4.NoIndex                       NaN
# 1883.2010.323A.Crump.Artic.LTREB.main.lane3.NoI...                      NaN
# 1883.2008.527.Crump.Artic.LTREB.main.lane3.NoIndex                      NaN
# 1883.2004.121.Crump.Artic.LTREB.main.lane1.NoIndex                      NaN
# 1883.2011.538.Crump.Artic.LTREB.main.lane3.NoIndex                      NaN
# 1883.2009.374.Crump.Artic.LTREB.main.lane3.NoIndex                      NaN
# 1883.2008.038.Crump.Artic.LTREB.main.lane2.NoIndex                      NaN
# 1883.2007.116.Crump.Artic.LTREB.main.lane2.NoIndex                      NaN
# 1883.2007.278.Crump.Artic.LTREB.main.lane2.NoIndex                      NaN
# 1883.2010.164.Crump.Artic.LTREB.main.lane3.NoIndex                      NaN
# 1883.2008.04.Crump.Artic.LTREB.main.lane2.NoIndex                       NaN
# 1883.2007.341.Crump.Artic.LTREB.main.lane2.NoIndex                      NaN
# 1883.2007.31.Crump.Artic.LTREB.main.lane2.NoIndex                       NaN
# 2382.SH004.C1.RH.5.421.bulk.4.12.lane7.NoIndex....                      NaN
# 10156.1S4                                                               NaN
# 10156.N1.2                                                              NaN
# 10245.68.Drnum7.day36.Bag8                                              NaN
# 10246.PP.B11                                                            0.0
# 10246.L.I5                                                              0.0
#
#                                                    ammonium nitrogen  \
# #SampleID
# 632.Agricultural.soil.soy                               NaN      NaN
# 678.OA.mesocosm.405                                     NaN      NaN
# 723.C6.3m.L3.Catlin1.16Spool.110602.HWI.EAS137R...      0.6      NaN
# 755.EFA.12.07.11.lane1.NoIndex.L001                   0.018      NaN
# 864.12.OTC.addV.noG.noW.lane2.NoIndex                   0.2      NaN
# 864.5.CON.addV.noG.noW.A.lane2.NoIndex                  0.0      NaN
# 889.25May.4                                             NaN      NaN
# 990.KA3U.B.13                                           NaN      NaN
# 990.KA2U.B.20                                           NaN      NaN
# 990.KA1F.B.09                                           NaN      NaN
# 990.KA2U.D.24                                           NaN      NaN
# 990.KA3U.A.11                                           NaN      NaN
# 990.KA2U.B.12                                           NaN      NaN
# 990.KA1F.D.16                                           NaN      NaN
# 1024.RU006.C181.RH.5.596.bulk.4.12.G1.L00               NaN      NaN
# 1031.HJDF3                                              NaN      NaN
# 1041.M028.10                                            NaN      NaN
# 1197.SE.20101009.GY.D019S.BC.217                         95      NaN
# 1222.B5.5.7.06                                          NaN      NaN
# 1240.1210T                                             0.04      NaN
# 1521.SK1.s.6.1.sequences                                NaN      NaN
# 1627.DRBC                                               NaN      NaN
# 1674.McG.F110715Ly6R3                                   NaN      NaN
# 1713.McG.L3B1020                                        NaN      NaN
# 1715.McG.NE1                                            NaN      NaN
# 1717.21.improved.leguminous                             NaN      NaN
# 1721.R15M                                               3.3      NaN
# 1721.S1B                                                6.3      NaN
# 1721.BMC.7.5T.21.3                                      NaN      NaN
# 1883.2010.026.Crump.Artic.LTREB.main.lane3.NoIndex      NaN      NaN
# 1883.2008.072.Crump.Artic.LTREB.main.lane2.NoIndex      NaN      NaN
# 1883.2007.359.Crump.Artic.LTREB.main.lane2.NoIndex      NaN      NaN
# 1883.2001.099.Crump.Artic.LTREB.main.lane1.NoIndex      NaN      NaN
# 1883.2010.268.Crump.Artic.LTREB.main.lane3.NoIndex      NaN      NaN
# 1883.2008.222.Crump.Artic.LTREB.main.lane2.NoIndex      NaN      NaN
# 1883.2004.208.Crump.Artic.LTREB.main.lane1.NoIndex      NaN      NaN
# 1883.2002.171.Crump.Artic.LTREB.main.lane1.NoIndex      NaN      NaN
# 1883.2010.273.Crump.Artic.LTREB.main.lane3.NoIndex      NaN      NaN
# 1883.2008.575.Crump.Artic.LTREB.main.lane4.NoIndex      NaN      NaN
# 1883.2006.182.Crump.Artic.LTREB.main.lane1.NoIndex      NaN      NaN
# 1883.2005.187.Crump.Artic.LTREB.main.lane4.NoIndex      NaN      NaN
# 1883.2011.188.Crump.Artic.LTREB.main.lane3.NoIndex      NaN      NaN
# 1883.2009.117.Crump.Artic.LTREB.main.lane3.NoIndex      NaN      NaN
# 1883.2007.515.Crump.Artic.LTREB.main.lane2.NoIndex      NaN      NaN
# 1883.2004.132.Crump.Artic.LTREB.main.lane1.NoIndex      NaN      NaN
# 1883.2011.488.Crump.Artic.LTREB.main.lane4.NoIndex      NaN      NaN
# 1883.2010.347.Crump.Artic.LTREB.main.lane3.NoIndex      NaN      NaN
# 1883.2008.501.Crump.Artic.LTREB.main.lane3.NoIndex      NaN      NaN
# 1883.2004.137.Crump.Artic.LTREB.main.lane1.NoIndex      NaN      NaN
# 1883.2011.41.Crump.Artic.LTREB.main.lane4.NoIndex       NaN      NaN
# 1883.2010.323A.Crump.Artic.LTREB.main.lane3.NoI...      NaN      NaN
# 1883.2008.527.Crump.Artic.LTREB.main.lane3.NoIndex      NaN      NaN
# 1883.2004.121.Crump.Artic.LTREB.main.lane1.NoIndex      NaN      NaN
# 1883.2011.538.Crump.Artic.LTREB.main.lane3.NoIndex      NaN      NaN
# 1883.2009.374.Crump.Artic.LTREB.main.lane3.NoIndex      NaN      NaN
# 1883.2008.038.Crump.Artic.LTREB.main.lane2.NoIndex      NaN      NaN
# 1883.2007.116.Crump.Artic.LTREB.main.lane2.NoIndex      NaN      NaN
# 1883.2007.278.Crump.Artic.LTREB.main.lane2.NoIndex      NaN      NaN
# 1883.2010.164.Crump.Artic.LTREB.main.lane3.NoIndex      NaN      NaN
# 1883.2008.04.Crump.Artic.LTREB.main.lane2.NoIndex       NaN      NaN
# 1883.2007.341.Crump.Artic.LTREB.main.lane2.NoIndex      NaN      NaN
# 1883.2007.31.Crump.Artic.LTREB.main.lane2.NoIndex       NaN      NaN
# 2382.SH004.C1.RH.5.421.bulk.4.12.lane7.NoIndex....      NaN      NaN
# 10156.1S4                                               NaN      NaN
# 10156.N1.2                                              NaN      NaN
# 10245.68.Drnum7.day36.Bag8                             30.0      2.0
# 10246.PP.B11                                            NaN      NaN
# 10246.L.I5                                              NaN      NaN
#
#                                                    nitrogen_percent  \
# #SampleID
# 632.Agricultural.soil.soy                                       NaN
# 678.OA.mesocosm.405                                             NaN
# 723.C6.3m.L3.Catlin1.16Spool.110602.HWI.EAS137R...              NaN
# 755.EFA.12.07.11.lane1.NoIndex.L001                             NaN
# 864.12.OTC.addV.noG.noW.lane2.NoIndex                           NaN
# 864.5.CON.addV.noG.noW.A.lane2.NoIndex                          NaN
# 889.25May.4                                                     NaN
# 990.KA3U.B.13                                                   NaN
# 990.KA2U.B.20                                                   NaN
# 990.KA1F.B.09                                                   NaN
# 990.KA2U.D.24                                                   NaN
# 990.KA3U.A.11                                                   NaN
# 990.KA2U.B.12                                                   NaN
# 990.KA1F.D.16                                                   NaN
# 1024.RU006.C181.RH.5.596.bulk.4.12.G1.L00                       NaN
# 1031.HJDF3                                                      NaN
# 1041.M028.10                                                    NaN
# 1197.SE.20101009.GY.D019S.BC.217                                NaN
# 1222.B5.5.7.06                                                  NaN
# 1240.1210T                                                      NaN
# 1521.SK1.s.6.1.sequences                                        NaN
# 1627.DRBC                                                       NaN
# 1674.McG.F110715Ly6R3                                           NaN
# 1713.McG.L3B1020                                                NaN
# 1715.McG.NE1                                                    NaN
# 1717.21.improved.leguminous                                     NaN
# 1721.R15M                                                       NaN
# 1721.S1B                                                        NaN
# 1721.BMC.7.5T.21.3                                              NaN
# 1883.2010.026.Crump.Artic.LTREB.main.lane3.NoIndex              NaN
# 1883.2008.072.Crump.Artic.LTREB.main.lane2.NoIndex              NaN
# 1883.2007.359.Crump.Artic.LTREB.main.lane2.NoIndex              NaN
# 1883.2001.099.Crump.Artic.LTREB.main.lane1.NoIndex              NaN
# 1883.2010.268.Crump.Artic.LTREB.main.lane3.NoIndex              NaN
# 1883.2008.222.Crump.Artic.LTREB.main.lane2.NoIndex              NaN
# 1883.2004.208.Crump.Artic.LTREB.main.lane1.NoIndex              NaN
# 1883.2002.171.Crump.Artic.LTREB.main.lane1.NoIndex              NaN
# 1883.2010.273.Crump.Artic.LTREB.main.lane3.NoIndex              NaN
# 1883.2008.575.Crump.Artic.LTREB.main.lane4.NoIndex              NaN
# 1883.2006.182.Crump.Artic.LTREB.main.lane1.NoIndex              NaN
# 1883.2005.187.Crump.Artic.LTREB.main.lane4.NoIndex              NaN
# 1883.2011.188.Crump.Artic.LTREB.main.lane3.NoIndex              NaN
# 1883.2009.117.Crump.Artic.LTREB.main.lane3.NoIndex              NaN
# 1883.2007.515.Crump.Artic.LTREB.main.lane2.NoIndex              NaN
# 1883.2004.132.Crump.Artic.LTREB.main.lane1.NoIndex              NaN
# 1883.2011.488.Crump.Artic.LTREB.main.lane4.NoIndex              NaN
# 1883.2010.347.Crump.Artic.LTREB.main.lane3.NoIndex              NaN
# 1883.2008.501.Crump.Artic.LTREB.main.lane3.NoIndex              NaN
# 1883.2004.137.Crump.Artic.LTREB.main.lane1.NoIndex              NaN
# 1883.2011.41.Crump.Artic.LTREB.main.lane4.NoIndex               NaN
# 1883.2010.323A.Crump.Artic.LTREB.main.lane3.NoI...              NaN
# 1883.2008.527.Crump.Artic.LTREB.main.lane3.NoIndex              NaN
# 1883.2004.121.Crump.Artic.LTREB.main.lane1.NoIndex              NaN
# 1883.2011.538.Crump.Artic.LTREB.main.lane3.NoIndex              NaN
# 1883.2009.374.Crump.Artic.LTREB.main.lane3.NoIndex              NaN
# 1883.2008.038.Crump.Artic.LTREB.main.lane2.NoIndex              NaN
# 1883.2007.116.Crump.Artic.LTREB.main.lane2.NoIndex              NaN
# 1883.2007.278.Crump.Artic.LTREB.main.lane2.NoIndex              NaN
# 1883.2010.164.Crump.Artic.LTREB.main.lane3.NoIndex              NaN
# 1883.2008.04.Crump.Artic.LTREB.main.lane2.NoIndex               NaN
# 1883.2007.341.Crump.Artic.LTREB.main.lane2.NoIndex              NaN
# 1883.2007.31.Crump.Artic.LTREB.main.lane2.NoIndex               NaN
# 2382.SH004.C1.RH.5.421.bulk.4.12.lane7.NoIndex....              NaN
# 10156.1S4                                                   0.06403
# 10156.N1.2                                                   9999.0
# 10245.68.Drnum7.day36.Bag8                                      NaN
# 10246.PP.B11                                                    NaN
# 10246.L.I5                                                      NaN
#
#                                                    tot_nitro_percent  \
# #SampleID
# 632.Agricultural.soil.soy                                        NaN
# 678.OA.mesocosm.405                                              NaN
# 723.C6.3m.L3.Catlin1.16Spool.110602.HWI.EAS137R...               NaN
# 755.EFA.12.07.11.lane1.NoIndex.L001                              NaN
# 864.12.OTC.addV.noG.noW.lane2.NoIndex                            NaN
# 864.5.CON.addV.noG.noW.A.lane2.NoIndex                           NaN
# 889.25May.4                                                      NaN
# 990.KA3U.B.13                                                    NaN
# 990.KA2U.B.20                                                    NaN
# 990.KA1F.B.09                                                    NaN
# 990.KA2U.D.24                                                    NaN
# 990.KA3U.A.11                                                    NaN
# 990.KA2U.B.12                                                    NaN
# 990.KA1F.D.16                                                    NaN
# 1024.RU006.C181.RH.5.596.bulk.4.12.G1.L00                        NaN
# 1031.HJDF3                                                       NaN
# 1041.M028.10                                                     NaN
# 1197.SE.20101009.GY.D019S.BC.217                                 NaN
# 1222.B5.5.7.06                                                   NaN
# 1240.1210T                                                       NaN
# 1521.SK1.s.6.1.sequences                                         NaN
# 1627.DRBC                                                      0.487
# 1674.McG.F110715Ly6R3                                            NaN
# 1713.McG.L3B1020                                                 NaN
# 1715.McG.NE1                                                     NaN
# 1717.21.improved.leguminous                                      NaN
# 1721.R15M                                                        NaN
# 1721.S1B                                                         NaN
# 1721.BMC.7.5T.21.3                                               NaN
# 1883.2010.026.Crump.Artic.LTREB.main.lane3.NoIndex               NaN
# 1883.2008.072.Crump.Artic.LTREB.main.lane2.NoIndex               NaN
# 1883.2007.359.Crump.Artic.LTREB.main.lane2.NoIndex               NaN
# 1883.2001.099.Crump.Artic.LTREB.main.lane1.NoIndex               NaN
# 1883.2010.268.Crump.Artic.LTREB.main.lane3.NoIndex               NaN
# 1883.2008.222.Crump.Artic.LTREB.main.lane2.NoIndex               NaN
# 1883.2004.208.Crump.Artic.LTREB.main.lane1.NoIndex               NaN
# 1883.2002.171.Crump.Artic.LTREB.main.lane1.NoIndex               NaN
# 1883.2010.273.Crump.Artic.LTREB.main.lane3.NoIndex               NaN
# 1883.2008.575.Crump.Artic.LTREB.main.lane4.NoIndex               NaN
# 1883.2006.182.Crump.Artic.LTREB.main.lane1.NoIndex               NaN
# 1883.2005.187.Crump.Artic.LTREB.main.lane4.NoIndex               NaN
# 1883.2011.188.Crump.Artic.LTREB.main.lane3.NoIndex               NaN
# 1883.2009.117.Crump.Artic.LTREB.main.lane3.NoIndex               NaN
# 1883.2007.515.Crump.Artic.LTREB.main.lane2.NoIndex               NaN
# 1883.2004.132.Crump.Artic.LTREB.main.lane1.NoIndex               NaN
# 1883.2011.488.Crump.Artic.LTREB.main.lane4.NoIndex               NaN
# 1883.2010.347.Crump.Artic.LTREB.main.lane3.NoIndex               NaN
# 1883.2008.501.Crump.Artic.LTREB.main.lane3.NoIndex               NaN
# 1883.2004.137.Crump.Artic.LTREB.main.lane1.NoIndex               NaN
# 1883.2011.41.Crump.Artic.LTREB.main.lane4.NoIndex                NaN
# 1883.2010.323A.Crump.Artic.LTREB.main.lane3.NoI...               NaN
# 1883.2008.527.Crump.Artic.LTREB.main.lane3.NoIndex               NaN
# 1883.2004.121.Crump.Artic.LTREB.main.lane1.NoIndex               NaN
# 1883.2011.538.Crump.Artic.LTREB.main.lane3.NoIndex               NaN
# 1883.2009.374.Crump.Artic.LTREB.main.lane3.NoIndex               NaN
# 1883.2008.038.Crump.Artic.LTREB.main.lane2.NoIndex               NaN
# 1883.2007.116.Crump.Artic.LTREB.main.lane2.NoIndex               NaN
# 1883.2007.278.Crump.Artic.LTREB.main.lane2.NoIndex               NaN
# 1883.2010.164.Crump.Artic.LTREB.main.lane3.NoIndex               NaN
# 1883.2008.04.Crump.Artic.LTREB.main.lane2.NoIndex                NaN
# 1883.2007.341.Crump.Artic.LTREB.main.lane2.NoIndex               NaN
# 1883.2007.31.Crump.Artic.LTREB.main.lane2.NoIndex                NaN
# 2382.SH004.C1.RH.5.421.bulk.4.12.lane7.NoIndex....               NaN
# 10156.1S4                                                        NaN
# 10156.N1.2                                                       NaN
# 10245.68.Drnum7.day36.Bag8                                       NaN
# 10246.PP.B11                                                     NaN
# 10246.L.I5                                                       NaN
#
#                                                              ...             \
# #SampleID                                                    ...
# 632.Agricultural.soil.soy                                    ...
# 678.OA.mesocosm.405                                          ...
# 723.C6.3m.L3.Catlin1.16Spool.110602.HWI.EAS137R...           ...
# 755.EFA.12.07.11.lane1.NoIndex.L001                          ...
# 864.12.OTC.addV.noG.noW.lane2.NoIndex                        ...
# 864.5.CON.addV.noG.noW.A.lane2.NoIndex                       ...
# 889.25May.4                                                  ...
# 990.KA3U.B.13                                                ...
# 990.KA2U.B.20                                                ...
# 990.KA1F.B.09                                                ...
# 990.KA2U.D.24                                                ...
# 990.KA3U.A.11                                                ...
# 990.KA2U.B.12                                                ...
# 990.KA1F.D.16                                                ...
# 1024.RU006.C181.RH.5.596.bulk.4.12.G1.L00                    ...
# 1031.HJDF3                                                   ...
# 1041.M028.10                                                 ...
# 1197.SE.20101009.GY.D019S.BC.217                             ...
# 1222.B5.5.7.06                                               ...
# 1240.1210T                                                   ...
# 1521.SK1.s.6.1.sequences                                     ...
# 1627.DRBC                                                    ...
# 1674.McG.F110715Ly6R3                                        ...
# 1713.McG.L3B1020                                             ...
# 1715.McG.NE1                                                 ...
# 1717.21.improved.leguminous                                  ...
# 1721.R15M                                                    ...
# 1721.S1B                                                     ...
# 1721.BMC.7.5T.21.3                                           ...
# 1883.2010.026.Crump.Artic.LTREB.main.lane3.NoIndex           ...
# 1883.2008.072.Crump.Artic.LTREB.main.lane2.NoIndex           ...
# 1883.2007.359.Crump.Artic.LTREB.main.lane2.NoIndex           ...
# 1883.2001.099.Crump.Artic.LTREB.main.lane1.NoIndex           ...
# 1883.2010.268.Crump.Artic.LTREB.main.lane3.NoIndex           ...
# 1883.2008.222.Crump.Artic.LTREB.main.lane2.NoIndex           ...
# 1883.2004.208.Crump.Artic.LTREB.main.lane1.NoIndex           ...
# 1883.2002.171.Crump.Artic.LTREB.main.lane1.NoIndex           ...
# 1883.2010.273.Crump.Artic.LTREB.main.lane3.NoIndex           ...
# 1883.2008.575.Crump.Artic.LTREB.main.lane4.NoIndex           ...
# 1883.2006.182.Crump.Artic.LTREB.main.lane1.NoIndex           ...
# 1883.2005.187.Crump.Artic.LTREB.main.lane4.NoIndex           ...
# 1883.2011.188.Crump.Artic.LTREB.main.lane3.NoIndex           ...
# 1883.2009.117.Crump.Artic.LTREB.main.lane3.NoIndex           ...
# 1883.2007.515.Crump.Artic.LTREB.main.lane2.NoIndex           ...
# 1883.2004.132.Crump.Artic.LTREB.main.lane1.NoIndex           ...
# 1883.2011.488.Crump.Artic.LTREB.main.lane4.NoIndex           ...
# 1883.2010.347.Crump.Artic.LTREB.main.lane3.NoIndex           ...
# 1883.2008.501.Crump.Artic.LTREB.main.lane3.NoIndex           ...
# 1883.2004.137.Crump.Artic.LTREB.main.lane1.NoIndex           ...
# 1883.2011.41.Crump.Artic.LTREB.main.lane4.NoIndex            ...
# 1883.2010.323A.Crump.Artic.LTREB.main.lane3.NoI...           ...
# 1883.2008.527.Crump.Artic.LTREB.main.lane3.NoIndex           ...
# 1883.2004.121.Crump.Artic.LTREB.main.lane1.NoIndex           ...
# 1883.2011.538.Crump.Artic.LTREB.main.lane3.NoIndex           ...
# 1883.2009.374.Crump.Artic.LTREB.main.lane3.NoIndex           ...
# 1883.2008.038.Crump.Artic.LTREB.main.lane2.NoIndex           ...
# 1883.2007.116.Crump.Artic.LTREB.main.lane2.NoIndex           ...
# 1883.2007.278.Crump.Artic.LTREB.main.lane2.NoIndex           ...
# 1883.2010.164.Crump.Artic.LTREB.main.lane3.NoIndex           ...
# 1883.2008.04.Crump.Artic.LTREB.main.lane2.NoIndex            ...
# 1883.2007.341.Crump.Artic.LTREB.main.lane2.NoIndex           ...
# 1883.2007.31.Crump.Artic.LTREB.main.lane2.NoIndex            ...
# 2382.SH004.C1.RH.5.421.bulk.4.12.lane7.NoIndex....           ...
# 10156.1S4                                                    ...
# 10156.N1.2                                                   ...
# 10245.68.Drnum7.day36.Bag8                                   ...
# 10246.PP.B11                                                 ...
# 10246.L.I5                                                   ...
#
#                                                    nitrogen_saturation  \
# #SampleID
# 632.Agricultural.soil.soy                                          NaN
# 678.OA.mesocosm.405                                                NaN
# 723.C6.3m.L3.Catlin1.16Spool.110602.HWI.EAS137R...                 NaN
# 755.EFA.12.07.11.lane1.NoIndex.L001                                NaN
# 864.12.OTC.addV.noG.noW.lane2.NoIndex                              NaN
# 864.5.CON.addV.noG.noW.A.lane2.NoIndex                             NaN
# 889.25May.4                                                        NaN
# 990.KA3U.B.13                                                      NaN
# 990.KA2U.B.20                                                      NaN
# 990.KA1F.B.09                                                      NaN
# 990.KA2U.D.24                                                      NaN
# ...
# 990.KA3U.A.11                                                                   Dry_combustion
# 990.KA2U.B.12                                                                   Dry_combustion
# 990.KA1F.D.16                                                                   Dry_combustion
# 1024.RU006.C181.RH.5.596.bulk.4.12.G1.L00                                                  NaN
# 1031.HJDF3                                                                          combustion
# 1041.M028.10                                                                               NaN
# 1197.SE.20101009.GY.D019S.BC.217                                                           NaN
# 1222.B5.5.7.06                                                                             NaN
# 1240.1210T                                                                                 NaN
# 1521.SK1.s.6.1.sequences                                                                   NaN
# 1627.DRBC                                                                                  NaN
# 1674.McG.F110715Ly6R3                                                                      NaN
# 1713.McG.L3B1020                                                                           NaN
# 1715.McG.NE1                                                                               NaN
# 1717.21.improved.leguminous                                                                NaN
# 1721.R15M                                                                                  NaN
# 1721.S1B                                                                                   NaN
# 1721.BMC.7.5T.21.3                                                                         NaN
# 1883.2010.026.Crump.Artic.LTREB.main.lane3.NoIndex                                         NaN
# 1883.2008.072.Crump.Artic.LTREB.main.lane2.NoIndex                                         NaN
# 1883.2007.359.Crump.Artic.LTREB.main.lane2.NoIndex                                         NaN
# 1883.2001.099.Crump.Artic.LTREB.main.lane1.NoIndex                                         NaN
# 1883.2010.268.Crump.Artic.LTREB.main.lane3.NoIndex                                         NaN
# 1883.2008.222.Crump.Artic.LTREB.main.lane2.NoIndex                                         NaN
# 1883.2004.208.Crump.Artic.LTREB.main.lane1.NoIndex                                         NaN
# 1883.2002.171.Crump.Artic.LTREB.main.lane1.NoIndex                                         NaN
# 1883.2010.273.Crump.Artic.LTREB.main.lane3.NoIndex                                         NaN
# 1883.2008.575.Crump.Artic.LTREB.main.lane4.NoIndex                                         NaN
# 1883.2006.182.Crump.Artic.LTREB.main.lane1.NoIndex                                         NaN
# 1883.2005.187.Crump.Artic.LTREB.main.lane4.NoIndex                                         NaN
# 1883.2011.188.Crump.Artic.LTREB.main.lane3.NoIndex                                         NaN
# 1883.2009.117.Crump.Artic.LTREB.main.lane3.NoIndex                                         NaN
# 1883.2007.515.Crump.Artic.LTREB.main.lane2.NoIndex                                         NaN
# 1883.2004.132.Crump.Artic.LTREB.main.lane1.NoIndex                                         NaN
# 1883.2011.488.Crump.Artic.LTREB.main.lane4.NoIndex                                         NaN
# 1883.2010.347.Crump.Artic.LTREB.main.lane3.NoIndex                                         NaN
# 1883.2008.501.Crump.Artic.LTREB.main.lane3.NoIndex                                         NaN
# 1883.2004.137.Crump.Artic.LTREB.main.lane1.NoIndex                                         NaN
# 1883.2011.41.Crump.Artic.LTREB.main.lane4.NoIndex                                          NaN
# 1883.2010.323A.Crump.Artic.LTREB.main.lane3.NoI...                                         NaN
# 1883.2008.527.Crump.Artic.LTREB.main.lane3.NoIndex                                         NaN
# 1883.2004.121.Crump.Artic.LTREB.main.lane1.NoIndex                                         NaN
# 1883.2011.538.Crump.Artic.LTREB.main.lane3.NoIndex                                         NaN
# 1883.2009.374.Crump.Artic.LTREB.main.lane3.NoIndex                                         NaN
# 1883.2008.038.Crump.Artic.LTREB.main.lane2.NoIndex                                         NaN
# 1883.2007.116.Crump.Artic.LTREB.main.lane2.NoIndex                                         NaN
# 1883.2007.278.Crump.Artic.LTREB.main.lane2.NoIndex                                         NaN
# 1883.2010.164.Crump.Artic.LTREB.main.lane3.NoIndex                                         NaN
# 1883.2008.04.Crump.Artic.LTREB.main.lane2.NoIndex                                          NaN
# 1883.2007.341.Crump.Artic.LTREB.main.lane2.NoIndex                                         NaN
# 1883.2007.31.Crump.Artic.LTREB.main.lane2.NoIndex                                          NaN
# 2382.SH004.C1.RH.5.421.bulk.4.12.lane7.NoIndex....                                         NaN
# 10156.1S4                                                                                  NaN
# 10156.N1.2                                                                                 NaN
# 10245.68.Drnum7.day36.Bag8                                                                 NaN
# 10246.PP.B11                                                                               NaN
# 10246.L.I5                                                                                 NaN
#
#                                                    tot_nitro_units  \
# #SampleID
# 632.Agricultural.soil.soy                                      NaN
# 678.OA.mesocosm.405                                            NaN
# 723.C6.3m.L3.Catlin1.16Spool.110602.HWI.EAS137R...             NaN
# 755.EFA.12.07.11.lane1.NoIndex.L001                            NaN
# 864.12.OTC.addV.noG.noW.lane2.NoIndex                          NaN
# 864.5.CON.addV.noG.noW.A.lane2.NoIndex                         NaN
# 889.25May.4                                                    NaN
# 990.KA3U.B.13                                                  NaN
# 990.KA2U.B.20                                                  NaN
# 990.KA1F.B.09                                                  NaN
# 990.KA2U.D.24                                                  NaN
# 990.KA3U.A.11                                                  NaN
# 990.KA2U.B.12                                                  NaN
# 990.KA1F.D.16                                                  NaN
# 1024.RU006.C181.RH.5.596.bulk.4.12.G1.L00                      NaN
# 1031.HJDF3                                                     NaN
# 1041.M028.10                                                   NaN
# 1197.SE.20101009.GY.D019S.BC.217                               NaN
# 1222.B5.5.7.06                                                 NaN
# 1240.1210T                                                     NaN
# 1521.SK1.s.6.1.sequences                                       NaN
# 1627.DRBC                                                      NaN
# 1674.McG.F110715Ly6R3                                          NaN
# 1713.McG.L3B1020                                               NaN
# 1715.McG.NE1                                                   NaN
# 1717.21.improved.leguminous                                    NaN
# 1721.R15M                                                      NaN
# 1721.S1B                                                       NaN
# 1721.BMC.7.5T.21.3                                             NaN
# 1883.2010.026.Crump.Artic.LTREB.main.lane3.NoIndex             NaN
# 1883.2008.072.Crump.Artic.LTREB.main.lane2.NoIndex             NaN
# 1883.2007.359.Crump.Artic.LTREB.main.lane2.NoIndex             NaN
# 1883.2001.099.Crump.Artic.LTREB.main.lane1.NoIndex             NaN
# 1883.2010.268.Crump.Artic.LTREB.main.lane3.NoIndex             NaN
# 1883.2008.222.Crump.Artic.LTREB.main.lane2.NoIndex             NaN
# 1883.2004.208.Crump.Artic.LTREB.main.lane1.NoIndex             NaN
# 1883.2002.171.Crump.Artic.LTREB.main.lane1.NoIndex             NaN
# 1883.2010.273.Crump.Artic.LTREB.main.lane3.NoIndex             NaN
# 1883.2008.575.Crump.Artic.LTREB.main.lane4.NoIndex             NaN
# 1883.2006.182.Crump.Artic.LTREB.main.lane1.NoIndex             NaN
# 1883.2005.187.Crump.Artic.LTREB.main.lane4.NoIndex             NaN
# 1883.2011.188.Crump.Artic.LTREB.main.lane3.NoIndex             NaN
# 1883.2009.117.Crump.Artic.LTREB.main.lane3.NoIndex             NaN
# 1883.2007.515.Crump.Artic.LTREB.main.lane2.NoIndex             NaN
# 1883.2004.132.Crump.Artic.LTREB.main.lane1.NoIndex             NaN
# 1883.2011.488.Crump.Artic.LTREB.main.lane4.NoIndex             NaN
# 1883.2010.347.Crump.Artic.LTREB.main.lane3.NoIndex             NaN
# 1883.2008.501.Crump.Artic.LTREB.main.lane3.NoIndex             NaN
# 1883.2004.137.Crump.Artic.LTREB.main.lane1.NoIndex             NaN
# 1883.2011.41.Crump.Artic.LTREB.main.lane4.NoIndex              NaN
# 1883.2010.323A.Crump.Artic.LTREB.main.lane3.NoI...             NaN
# 1883.2008.527.Crump.Artic.LTREB.main.lane3.NoIndex             NaN
# 1883.2004.121.Crump.Artic.LTREB.main.lane1.NoIndex             NaN
# 1883.2011.538.Crump.Artic.LTREB.main.lane3.NoIndex             NaN
# 1883.2009.374.Crump.Artic.LTREB.main.lane3.NoIndex             NaN
# 1883.2008.038.Crump.Artic.LTREB.main.lane2.NoIndex             NaN
# 1883.2007.116.Crump.Artic.LTREB.main.lane2.NoIndex             NaN
# 1883.2007.278.Crump.Artic.LTREB.main.lane2.NoIndex             NaN
# 1883.2010.164.Crump.Artic.LTREB.main.lane3.NoIndex             NaN
# 1883.2008.04.Crump.Artic.LTREB.main.lane2.NoIndex              NaN
# 1883.2007.341.Crump.Artic.LTREB.main.lane2.NoIndex             NaN
# 1883.2007.31.Crump.Artic.LTREB.main.lane2.NoIndex              NaN
# 2382.SH004.C1.RH.5.421.bulk.4.12.lane7.NoIndex....             NaN
# 10156.1S4                                                      NaN
# 10156.N1.2                                                     NaN
# 10245.68.Drnum7.day36.Bag8                                     NaN
# 10246.PP.B11                                                   NaN
# 10246.L.I5                                                     NaN
#
#                                                    treatment_3_urea_815g_ha
# #SampleID
# 632.Agricultural.soil.soy                                               NaN
# 678.OA.mesocosm.405                                                     NaN
# 723.C6.3m.L3.Catlin1.16Spool.110602.HWI.EAS137R...                      NaN
# 755.EFA.12.07.11.lane1.NoIndex.L001                                     NaN
# 864.12.OTC.addV.noG.noW.lane2.NoIndex                                   NaN
# 864.5.CON.addV.noG.noW.A.lane2.NoIndex                                  NaN
# 889.25May.4                                                             NaN
# 990.KA3U.B.13                                                           NaN
# 990.KA2U.B.20                                                           NaN
# 990.KA1F.B.09                                                           NaN
# 990.KA2U.D.24                                                           NaN
# 990.KA3U.A.11                                                           NaN
# 990.KA2U.B.12                                                           NaN
# 990.KA1F.D.16                                                           NaN
# 1024.RU006.C181.RH.5.596.bulk.4.12.G1.L00                               NaN
# 1031.HJDF3                                                              NaN
# 1041.M028.10                                                            NaN
# 1197.SE.20101009.GY.D019S.BC.217                                        NaN
# 1222.B5.5.7.06                                                          NaN
# 1240.1210T                                                              NaN
# 1521.SK1.s.6.1.sequences                                                NaN
# 1627.DRBC                                                               NaN
# 1674.McG.F110715Ly6R3                                                   NaN
# 1713.McG.L3B1020                                                        NaN
# 1715.McG.NE1                                                            NaN
# 1717.21.improved.leguminous                                             NaN
# 1721.R15M                                                                 n
# 1721.S1B                                                                  n
# 1721.BMC.7.5T.21.3                                                      NaN
# 1883.2010.026.Crump.Artic.LTREB.main.lane3.NoIndex                      NaN
# 1883.2008.072.Crump.Artic.LTREB.main.lane2.NoIndex                      NaN
# 1883.2007.359.Crump.Artic.LTREB.main.lane2.NoIndex                      NaN
# 1883.2001.099.Crump.Artic.LTREB.main.lane1.NoIndex                      NaN
# 1883.2010.268.Crump.Artic.LTREB.main.lane3.NoIndex                      NaN
# 1883.2008.222.Crump.Artic.LTREB.main.lane2.NoIndex                      NaN
# 1883.2004.208.Crump.Artic.LTREB.main.lane1.NoIndex                      NaN
# 1883.2002.171.Crump.Artic.LTREB.main.lane1.NoIndex                      NaN
# 1883.2010.273.Crump.Artic.LTREB.main.lane3.NoIndex                      NaN
# 1883.2008.575.Crump.Artic.LTREB.main.lane4.NoIndex                      NaN
# 1883.2006.182.Crump.Artic.LTREB.main.lane1.NoIndex                      NaN
# 1883.2005.187.Crump.Artic.LTREB.main.lane4.NoIndex                      NaN
# 1883.2011.188.Crump.Artic.LTREB.main.lane3.NoIndex                      NaN
# 1883.2009.117.Crump.Artic.LTREB.main.lane3.NoIndex                      NaN
# 1883.2007.515.Crump.Artic.LTREB.main.lane2.NoIndex                      NaN
# 1883.2004.132.Crump.Artic.LTREB.main.lane1.NoIndex                      NaN
# 1883.2011.488.Crump.Artic.LTREB.main.lane4.NoIndex                      NaN
# 1883.2010.347.Crump.Artic.LTREB.main.lane3.NoIndex                      NaN
# 1883.2008.501.Crump.Artic.LTREB.main.lane3.NoIndex                      NaN
# 1883.2004.137.Crump.Artic.LTREB.main.lane1.NoIndex                      NaN
# 1883.2011.41.Crump.Artic.LTREB.main.lane4.NoIndex                       NaN
# 1883.2010.323A.Crump.Artic.LTREB.main.lane3.NoI...                      NaN
# 1883.2008.527.Crump.Artic.LTREB.main.lane3.NoIndex                      NaN
# 1883.2004.121.Crump.Artic.LTREB.main.lane1.NoIndex                      NaN
# 1883.2011.538.Crump.Artic.LTREB.main.lane3.NoIndex                      NaN
# 1883.2009.374.Crump.Artic.LTREB.main.lane3.NoIndex                      NaN
# 1883.2008.038.Crump.Artic.LTREB.main.lane2.NoIndex                      NaN
# 1883.2007.116.Crump.Artic.LTREB.main.lane2.NoIndex                      NaN
# 1883.2007.278.Crump.Artic.LTREB.main.lane2.NoIndex                      NaN
# 1883.2010.164.Crump.Artic.LTREB.main.lane3.NoIndex                      NaN
# 1883.2008.04.Crump.Artic.LTREB.main.lane2.NoIndex                       NaN
# 1883.2007.341.Crump.Artic.LTREB.main.lane2.NoIndex                      NaN
# 1883.2007.31.Crump.Artic.LTREB.main.lane2.NoIndex                       NaN
# 2382.SH004.C1.RH.5.421.bulk.4.12.lane7.NoIndex....                      NaN
# 10156.1S4                                                               NaN
# 10156.N1.2                                                              NaN
# 10245.68.Drnum7.day36.Bag8                                              NaN
# 10246.PP.B11                                                            NaN
# 10246.L.I5                                                              NaN
#
# [68 rows x 37 columns]

# %%
# list of studies with either P or N data, so that we can contact collaborators to determine units
studies_phos_nitr = set(df_refined.loc[df_phos.index].study_id) | set(df_refined.loc[df_nitr.index].study_id)
list_email = []
for study in studies_phos_nitr:
    list_email.append(dict_email[study])

# %%
set(list_email)
# Out:
# {nan,
#  u'Aurora MacRae-Crerar, aurorama@sas.upenn.edu, Jack, Sarah',
#  u'Hychu@issas.ac.cn',
#  u'Stefan.Hulth@chem.gu.se',
#  u'apre@pml.ac.uk',
#  u'b.laverock@gmail.com',
#  u'bcrump@coas.oregonstate.edu',
#  u'c.robinson@uea.ac.uk',
#  u'david.myrold@oregonstate.edu',
#  u'dion@anl.gov',
#  u'ercolini@unina.it',
#  u'gail.ackermann@colorado.edu',
#  u'gilbertjack@gmail.com',
#  u'hefi@pml.ac.uk',
#  u'itimling@alaska.edu',
#  u'jandras@cornell.edu',
#  u'janet.jansson@pnnl.gov',
#  u'jneufeld@uwaterloo.ca',
#  u'kmcguire@barnard.edu',
#  u'krockne@uic.edu',
#  u'lmseyler@gmail.com',
#  u'morganr2@muohio.edu',
#  u's.haig.1@research.gla.ac.uk',
#  u'saman.bowatte@agresearch.co.nz',
#  u'skennedy@mobio.com',
#  u'subbu36@gmail.com',
#  u't.thomas@unsw.edu.au',
#  u'wbrazelton@gmail.com'}

# %% [markdown]
# ### Hierarchical ENVO lookup (from Jad & Amnon)

# %% [markdown]
# ### Hierarchical taxonomy lookup (from Jon)

# %% [markdown]
# https://github.com/tanaes/script_bin/blob/master/humann2_full_tax.py#L170
#
# You need to:
#
#     from ete2 import NCBITaxa
#     ncbi = NCBITaxa()
#     lineage = get_taxon_path(best_id, ncbi, ranks=ranks, rank_headers=rank_headers)

# %% [markdown]
# ### List of studies with counts by empo_3 (minus blanks)

# %%
# filter out controls
df_refined_no_controls = df_refined[df_refined['empo_1'] != 'Control']

# %%
# count the number of samples per study_id/title and empo_3 (use BarcodeSequence to get the count)
studies_groupby = df_refined_no_controls.groupby(['study_id', 'title', 'empo_3']).count()
studies_groupby_unstack = studies_groupby['BarcodeSequence'].unstack()

# %%
# add sum column
studies_groupby_unstack['Total'] = studies_groupby_unstack.sum(axis=1)

# %%
df_refined
# Out:
#                         BarcodeSequence LinkerPrimerSequence  \
# #SampleID
# 550.L1S1.s.1.sequence      AACGCACGCTAG  GTGCCAGCMGCCGCGGTAA
# 550.L1S10.s.1.sequence     ACAGACCACTCA  GTGCCAGCMGCCGCGGTAA
# 550.L1S100.s.1.sequence    ATGCACTGGCGA  GTGCCAGCMGCCGCGGTAA
# 550.L1S101.s.1.sequence    ATTATCGTGCAC  GTGCCAGCMGCCGCGGTAA
# 550.L1S102.s.1.sequence    CACGACAGGCTA  GTGCCAGCMGCCGCGGTAA
# 550.L1S103.s.1.sequence    CAGATACACTTC  GTGCCAGCMGCCGCGGTAA
# 550.L1S104.s.1.sequence    CAGTGTCAGGAC  GTGCCAGCMGCCGCGGTAA
# 550.L1S105.s.1.sequence    AGTGCGATGCGT  GTGCCAGCMGCCGCGGTAA
# 550.L1S106.s.1.sequence    ATACTCACTCAG  GTGCCAGCMGCCGCGGTAA
# 550.L1S107.s.1.sequence    ATCGCTCGAGGA  GTGCCAGCMGCCGCGGTAA
# 550.L1S108.s.1.sequence    ATGCAGCTCAGT  GTGCCAGCMGCCGCGGTAA
# 550.L1S109.s.1.sequence    ATTCTGTGAGCG  GTGCCAGCMGCCGCGGTAA
# 550.L1S11.s.1.sequence     ACCAGCGACTAG  GTGCCAGCMGCCGCGGTAA
# 550.L1S110.s.1.sequence    CACGGACTATAC  GTGCCAGCMGCCGCGGTAA
# 550.L1S111.s.1.sequence    CAGATCGGATCG  GTGCCAGCMGCCGCGGTAA
# 550.L1S112.s.1.sequence    CATACCAGTAGC  GTGCCAGCMGCCGCGGTAA
# 550.L1S113.s.1.sequence    AGTGGATGCTCT  GTGCCAGCMGCCGCGGTAA
# 550.L1S114.s.1.sequence    ATAGCTCCATAC  GTGCCAGCMGCCGCGGTAA
# 550.L1S115.s.1.sequence    ATCGTACAACTC  GTGCCAGCMGCCGCGGTAA
# 550.L1S116.s.1.sequence    ATGCCTGAGCAG  GTGCCAGCMGCCGCGGTAA
# 550.L1S117.s.1.sequence    CAACACGCACGA  GTGCCAGCMGCCGCGGTAA
# 550.L1S118.s.1.sequence    CACGTCGATGGA  GTGCCAGCMGCCGCGGTAA
# 550.L1S119.s.1.sequence    CAGCACTAAGCG  GTGCCAGCMGCCGCGGTAA
# 550.L1S12.s.1.sequence     ACGGATCGTCAG  GTGCCAGCMGCCGCGGTAA
# 550.L1S120.s.1.sequence    CATAGACGTTCG  GTGCCAGCMGCCGCGGTAA
# 550.L1S121.s.1.sequence    AGTGTCACGGTG  GTGCCAGCMGCCGCGGTAA
# 550.L1S122.s.1.sequence    ATAGGCGATCTC  GTGCCAGCMGCCGCGGTAA
# 550.L1S123.s.1.sequence    ATCTACTACACG  GTGCCAGCMGCCGCGGTAA
# 550.L1S124.s.1.sequence    ATGCGTAGTGCG  GTGCCAGCMGCCGCGGTAA
# 550.L1S125.s.1.sequence    CAACTATCAGCT  GTGCCAGCMGCCGCGGTAA
# 550.L1S126.s.1.sequence    CACGTGACATGT  GTGCCAGCMGCCGCGGTAA
# 550.L1S127.s.1.sequence    CAGCATGTGTTG  GTGCCAGCMGCCGCGGTAA
# 550.L1S128.s.1.sequence    CATAGCGAGTTC  GTGCCAGCMGCCGCGGTAA
# 550.L1S129.s.1.sequence    AGTGTTCGATCG  GTGCCAGCMGCCGCGGTAA
# 550.L1S13.s.1.sequence     ACTCAGATACTC  GTGCCAGCMGCCGCGGTAA
# 550.L1S130.s.1.sequence    ATATCGCTACTG  GTGCCAGCMGCCGCGGTAA
# 550.L1S131.s.1.sequence    ATCTCTGGCATA  GTGCCAGCMGCCGCGGTAA
# 550.L1S132.s.1.sequence    ATGGATACGCTC  GTGCCAGCMGCCGCGGTAA
# 550.L1S133.s.1.sequence    CAACTCATCGTA  GTGCCAGCMGCCGCGGTAA
# 550.L1S134.s.1.sequence    CACTACTGTTGA  GTGCCAGCMGCCGCGGTAA
# 550.L1S135.s.1.sequence    CAGCGGTGACAT  GTGCCAGCMGCCGCGGTAA
# 550.L1S136.s.1.sequence    CATATACTCGCA  GTGCCAGCMGCCGCGGTAA
# 550.L1S137.s.1.sequence    AGTTAGTGCGTC  GTGCCAGCMGCCGCGGTAA
# 550.L1S138.s.1.sequence    ATATGCCAGTGC  GTGCCAGCMGCCGCGGTAA
# 550.L1S139.s.1.sequence    ATCTGAGCTGGT  GTGCCAGCMGCCGCGGTAA
# 550.L1S14.s.1.sequence     AGACGTGCACTG  GTGCCAGCMGCCGCGGTAA
# 550.L1S140.s.1.sequence    ATGGCAGCTCTA  GTGCCAGCMGCCGCGGTAA
# 550.L1S141.s.1.sequence    CAAGATCGACTC  GTGCCAGCMGCCGCGGTAA
# 550.L1S142.s.1.sequence    CACTCAACAGAC  GTGCCAGCMGCCGCGGTAA
# 550.L1S143.s.1.sequence    CAGCTAGAACGC  GTGCCAGCMGCCGCGGTAA
# 550.L1S144.s.1.sequence    CATATCGCAGTT  GTGCCAGCMGCCGCGGTAA
# 550.L1S145.s.1.sequence    AGTTCAGACGCT  GTGCCAGCMGCCGCGGTAA
# 550.L1S146.s.1.sequence    ATCACGTAGCGG  GTGCCAGCMGCCGCGGTAA
# 550.L1S147.s.1.sequence    ATCTGGTGCTAT  GTGCCAGCMGCCGCGGTAA
# 550.L1S148.s.1.sequence    ATGGCGTGCACA  GTGCCAGCMGCCGCGGTAA
# 550.L1S149.s.1.sequence    CAAGTGAGAGAG  GTGCCAGCMGCCGCGGTAA
# 550.L1S15.s.1.sequence     AGCAGCACTTGT  GTGCCAGCMGCCGCGGTAA
# 550.L1S150.s.1.sequence    CACTCTGATTAG  GTGCCAGCMGCCGCGGTAA
# 550.L1S151.s.1.sequence    CAGGTGCTACTA  GTGCCAGCMGCCGCGGTAA
# 550.L1S152.s.1.sequence    CATCAGCGTGTA  GTGCCAGCMGCCGCGGTAA
# 550.L1S153.s.1.sequence    AGTTCTACGTCA  GTGCCAGCMGCCGCGGTAA
# 550.L1S154.s.1.sequence    ATCACTAGTCAC  GTGCCAGCMGCCGCGGTAA
# 550.L1S155.s.1.sequence    ATCTTAGACTGC  GTGCCAGCMGCCGCGGTAA
# 550.L1S156.s.1.sequence    ATGGTCTACTAC  GTGCCAGCMGCCGCGGTAA
# 550.L1S157.s.1.sequence    CACACGTGAGCA  GTGCCAGCMGCCGCGGTAA
# 550.L1S158.s.1.sequence    CACTGGTATATC  GTGCCAGCMGCCGCGGTAA
# 550.L1S159.s.1.sequence    CAGTACGATCTT  GTGCCAGCMGCCGCGGTAA
# 550.L1S16.s.1.sequence     AGCTTGACAGCT  GTGCCAGCMGCCGCGGTAA
# 550.L1S160.s.1.sequence    CATCATGAGGCT  GTGCCAGCMGCCGCGGTAA
# 550.L1S161.s.1.sequence    ATAATCTCGTCG  GTGCCAGCMGCCGCGGTAA
# 550.L1S162.s.1.sequence    ATCAGGCGTGTG  GTGCCAGCMGCCGCGGTAA
# 550.L1S163.s.1.sequence    ATGACCATCGTG  GTGCCAGCMGCCGCGGTAA
# 550.L1S164.s.1.sequence    ATGTACGGCGAC  GTGCCAGCMGCCGCGGTAA
# 550.L1S165.s.1.sequence    CACAGCTCGAAT  GTGCCAGCMGCCGCGGTAA
# 550.L1S166.s.1.sequence    CACTGTAGGACG  GTGCCAGCMGCCGCGGTAA
# 550.L1S167.s.1.sequence    CAGTCACTAACG  GTGCCAGCMGCCGCGGTAA
# 550.L1S168.s.1.sequence    CATCGTATCAAC  GTGCCAGCMGCCGCGGTAA
# 550.L1S169.s.1.sequence    ATACACGTGGCG  GTGCCAGCMGCCGCGGTAA
# 550.L1S17.s.1.sequence     AACTGTGCGTAC  GTGCCAGCMGCCGCGGTAA
# 550.L1S170.s.1.sequence    ATCCGATCACAG  GTGCCAGCMGCCGCGGTAA
# 550.L1S171.s.1.sequence    ATGACTCATTCG  GTGCCAGCMGCCGCGGTAA
# 550.L1S172.s.1.sequence    ATGTCACCGTGA  GTGCCAGCMGCCGCGGTAA
# 550.L1S173.s.1.sequence    CACAGTGGACGT  GTGCCAGCMGCCGCGGTAA
# 550.L1S174.s.1.sequence    CAGACATTGCGT  GTGCCAGCMGCCGCGGTAA
# 550.L1S175.s.1.sequence    CAGTCGAAGCTG  GTGCCAGCMGCCGCGGTAA
# 550.L1S176.s.1.sequence    CATCTGTAGCGA  GTGCCAGCMGCCGCGGTAA
# 550.L1S177.s.1.sequence    ATACAGAGCTCC  GTGCCAGCMGCCGCGGTAA
# 550.L1S178.s.1.sequence    ATCCTCAGTAGT  GTGCCAGCMGCCGCGGTAA
# 550.L1S179.s.1.sequence    ATGAGACTCCAC  GTGCCAGCMGCCGCGGTAA
# 550.L1S18.s.1.sequence     ACAGAGTCGGCT  GTGCCAGCMGCCGCGGTAA
# 550.L1S180.s.1.sequence    ATGTGCACGACT  GTGCCAGCMGCCGCGGTAA
# 550.L1S181.s.1.sequence    CACATCTAACAC  GTGCCAGCMGCCGCGGTAA
# 550.L1S182.s.1.sequence    CAGACTCGCAGA  GTGCCAGCMGCCGCGGTAA
# 550.L1S183.s.1.sequence    CAGTGATCCTAG  GTGCCAGCMGCCGCGGTAA
# 550.L1S184.s.1.sequence    CATGAGTGCTAC  GTGCCAGCMGCCGCGGTAA
# 550.L1S185.s.1.sequence    ATACGTCTTCGA  GTGCCAGCMGCCGCGGTAA
# 550.L1S186.s.1.sequence    ATCGATCTGTGG  GTGCCAGCMGCCGCGGTAA
# 550.L1S187.s.1.sequence    ATGATCGAGAGA  GTGCCAGCMGCCGCGGTAA
# 550.L1S188.s.1.sequence    ATGTGTCGACTT  GTGCCAGCMGCCGCGGTAA
# 550.L1S189.s.1.sequence    CACATTGTGAGC  GTGCCAGCMGCCGCGGTAA
# ...                                 ...                  ...
# 10346.Webster.5.D10.422    CACTTTGGGTGC  GTGCCAGCMGCCGCGGTAA
# 10346.Webster.5.D11.423    TCTAGCCTGGCA  GTGCCAGCMGCCGCGGTAA
# 10346.Webster.5.D12.424    AATGCAATGCGT  GTGCCAGCMGCCGCGGTAA
# 10346.Webster.5.D1.413     ACATACTGAGCA  GTGCCAGCMGCCGCGGTAA
# 10346.Webster.5.D2.414     GGCTAAACTATG  GTGCCAGCMGCCGCGGTAA
# 10346.Webster.5.D3.415     AAGAGCAGAGCC  GTGCCAGCMGCCGCGGTAA
# 10346.Webster.5.D4.416     GGAGAGATCACG  GTGCCAGCMGCCGCGGTAA
# 10346.Webster.5.D5.417     TCAACCCGTGAA  GTGCCAGCMGCCGCGGTAA
# 10346.Webster.5.D6.418     GTTTGAAACACG  GTGCCAGCMGCCGCGGTAA
# 10346.Webster.5.D7.419     AGAGAGACAGGT  GTGCCAGCMGCCGCGGTAA
# 10346.Webster.5.D8.420     TCGCCAGTGCAT  GTGCCAGCMGCCGCGGTAA
# 10346.Webster.5.D9.421     GCTCAGGACTCT  GTGCCAGCMGCCGCGGTAA
# 10346.Webster.5.E1.425     CGAATGAGTCAT  GTGCCAGCMGCCGCGGTAA
# 10346.Webster.5.E2.426     CAACGCTAGAAT  GTGCCAGCMGCCGCGGTAA
# 10346.Webster.5.E3.427     ATCAGAGCCCAT  GTGCCAGCMGCCGCGGTAA
# 10346.Webster.5.E4.428     TCTGTAGAGCCA  GTGCCAGCMGCCGCGGTAA
# 10346.Webster.5.E5.429     CCGACTCTAGGT  GTGCCAGCMGCCGCGGTAA
# 10346.Webster.5.E6.430     ATCCTACGAGCA  GTGCCAGCMGCCGCGGTAA
# 10346.ZA.12                CGCTTAGTGCTG  GTGCCAGCMGCCGCGGTAA
# 10346.ZA.13                ACAAGAACCTTG  GTGCCAGCMGCCGCGGTAA
# 10346.ZA.14                AACTTCACTTCC  GTGCCAGCMGCCGCGGTAA
# 10346.ZA.15                TTACCGACGAGT  GTGCCAGCMGCCGCGGTAA
# 10346.ZA.16                TGAGGACTACCT  GTGCCAGCMGCCGCGGTAA
# 10346.ZA.17                GTAGACATGTGT  GTGCCAGCMGCCGCGGTAA
# 10346.ZA.37                CGTGCACAATTG  GTGCCAGCMGCCGCGGTAA
# 10346.ZA.38                GATAGCACTCGT  GTGCCAGCMGCCGCGGTAA
# 10346.ZA.39                CAAAGTTTGCGA  GTGCCAGCMGCCGCGGTAA
# 10346.ZA.40                TACTCTCTTAGC  GTGCCAGCMGCCGCGGTAA
# 10346.ZA.41                CCAGTGGATATA  GTGCCAGCMGCCGCGGTAA
# 10346.ZA.42                GCTTAGATGTAG  GTGCCAGCMGCCGCGGTAA
# 10346.ZA.44                CAATCGGCTTGC  GTGCCAGCMGCCGCGGTAA
# 10346.ZA.46                TACAGTTACGCG  GTGCCAGCMGCCGCGGTAA
# 10346.ZA.47                CGGCCTAAGTTC  GTGCCAGCMGCCGCGGTAA
# 10346.ZA.48                TAGCGCGAACTT  GTGCCAGCMGCCGCGGTAA
# 10346.ZA.49                TCGAGCCGATCT  GTGCCAGCMGCCGCGGTAA
# 10346.ZA.53                AACTGTTCGCGC  GTGCCAGCMGCCGCGGTAA
# 10363.AC1                  GCTTATTGCTTA  GTGCCAGCMGCCGCGGTAA
# 10363.AC10                 TTGGTGCCTGTG  GTGCCAGCMGCCGCGGTAA
# 10363.AC11                 GAATGACGTTTG  GTGCCAGCMGCCGCGGTAA
# 10363.AC12                 GAGCATTACATG  GTGCCAGCMGCCGCGGTAA
# 10363.AC13                 ATGCAACTCGAA  GTGCCAGCMGCCGCGGTAA
# 10363.AC14                 TCTGATCGAGGT  GTGCCAGCMGCCGCGGTAA
# 10363.AC15                 TTACCACATCTA  GTGCCAGCMGCCGCGGTAA
# 10363.AC16                 CATGAGACTGTA  GTGCCAGCMGCCGCGGTAA
# 10363.AC17                 GCAAGCTGTCTC  GTGCCAGCMGCCGCGGTAA
# 10363.AC18                 AAGCGTACATTG  GTGCCAGCMGCCGCGGTAA
# 10363.AC19                 AGAGCTCCTCTG  GTGCCAGCMGCCGCGGTAA
# 10363.AC2                  AACTGGAACCCT  GTGCCAGCMGCCGCGGTAA
# 10363.AC20                 ATAAAGAGGAGG  GTGCCAGCMGCCGCGGTAA
# 10363.AC21                 TGAGTTCGGTCC  GTGCCAGCMGCCGCGGTAA
# 10363.AC22                 CTAATATTTGAA  GTGCCAGCMGCCGCGGTAA
# 10363.AC23                 GGTCGAATTGCT  GTGCCAGCMGCCGCGGTAA
# 10363.AC24                 ACGCTCCCATCG  GTGCCAGCMGCCGCGGTAA
# 10363.AC25                 CTCAGGAGACTT  GTGCCAGCMGCCGCGGTAA
# 10363.AC26                 CACTCTCCGGCA  GTGCCAGCMGCCGCGGTAA
# 10363.AC27                 AGACAAGCTTCC  GTGCCAGCMGCCGCGGTAA
# 10363.AC28                 GCGTACGGGTGA  GTGCCAGCMGCCGCGGTAA
# 10363.AC29                 CATCCTGAGCAA  GTGCCAGCMGCCGCGGTAA
# 10363.AC3                  TCATGTGAACGA  GTGCCAGCMGCCGCGGTAA
# 10363.AC30                 AAGGTGGACAAG  GTGCCAGCMGCCGCGGTAA
# 10363.AC31                 ATGGCCTGACTA  GTGCCAGCMGCCGCGGTAA
# 10363.AC32                 GTGTGCTAACGT  GTGCCAGCMGCCGCGGTAA
# 10363.AC33                 GTCTATACATAT  GTGCCAGCMGCCGCGGTAA
# 10363.AC34                 GACCATGTAGTA  GTGCCAGCMGCCGCGGTAA
# 10363.AC35                 CTTTATGTGTCA  GTGCCAGCMGCCGCGGTAA
# 10363.AC36                 CAATATTCAATA  GTGCCAGCMGCCGCGGTAA
# 10363.AC37                 ACAAGTGCTGCT  GTGCCAGCMGCCGCGGTAA
# 10363.AC38                 CGTAAGATGCCT  GTGCCAGCMGCCGCGGTAA
# 10363.AC39                 CTTCGCGGATGT  GTGCCAGCMGCCGCGGTAA
# 10363.AC4                  GAGGTATTCTGA  GTGCCAGCMGCCGCGGTAA
# 10363.AC40                 ATCATCTCGGCG  GTGCCAGCMGCCGCGGTAA
# 10363.AC41                 GGTACTGTACCA  GTGCCAGCMGCCGCGGTAA
# 10363.AC42                 TATCTTCCTGAA  GTGCCAGCMGCCGCGGTAA
# 10363.AC43                 CGAGTATACAAC  GTGCCAGCMGCCGCGGTAA
# 10363.AC44                 TGAGCGCACGCG  GTGCCAGCMGCCGCGGTAA
# 10363.AC45                 TAAGCGTCTCGA  GTGCCAGCMGCCGCGGTAA
# 10363.AC46                 TATAATCCGAGG  GTGCCAGCMGCCGCGGTAA
# 10363.AC47                 TTACCCGCACAG  GTGCCAGCMGCCGCGGTAA
# 10363.AC48                 AACGTCCTGTGC  GTGCCAGCMGCCGCGGTAA
# 10363.AC49                 TGGCATGTTGGT  GTGCCAGCMGCCGCGGTAA
# 10363.AC5                  GAAGGAAAGTAG  GTGCCAGCMGCCGCGGTAA
# 10363.AC50                 TCAACTATGTCT  GTGCCAGCMGCCGCGGTAA
# 10363.AC51                 TCAATGACCGCA  GTGCCAGCMGCCGCGGTAA
# 10363.AC52                 AGTTCGGCATTG  GTGCCAGCMGCCGCGGTAA
# 10363.AC53                 ATTGGGACATAA  GTGCCAGCMGCCGCGGTAA
# 10363.AC54                 ATTAATGAAGCG  GTGCCAGCMGCCGCGGTAA
# 10363.AC55                 ATATACCTGCGG  GTGCCAGCMGCCGCGGTAA
# 10363.AC56                 GTGACTAGTGAT  GTGCCAGCMGCCGCGGTAA
# 10363.AC57                 TATAGAAGAATG  GTGCCAGCMGCCGCGGTAA
# 10363.AC58                 ATCACATTCTCC  GTGCCAGCMGCCGCGGTAA
# 10363.AC6                  GGAGGGTACCGT  GTGCCAGCMGCCGCGGTAA
# 10363.AC7                  CCAGGGACTTCT  GTGCCAGCMGCCGCGGTAA
# 10363.AC8                  AAGATTTGCAGC  GTGCCAGCMGCCGCGGTAA
# 10363.AC9                  AACCGATGTACC  GTGCCAGCMGCCGCGGTAA
# 10363.BLANK.CSU1.8C        TCAAGATCAAGA  GTGCCAGCMGCCGCGGTAA
# 10363.BLANK.CSU1.8D        CTGTTACAGCGA  GTGCCAGCMGCCGCGGTAA
# 10363.BLANK.CSU1.8E        AAGTGCTTGGTA  GTGCCAGCMGCCGCGGTAA
# 10363.BLANK.CSU1.8F        AGTTTGCGAGAT  GTGCCAGCMGCCGCGGTAA
# 10363.BLANK.CSU1.8G        CACTTGCTCTCT  GTGCCAGCMGCCGCGGTAA
# 10363.BLANK.CSU1.8H        AGGAATACTCAC  GTGCCAGCMGCCGCGGTAA
#
#                                                                Description  \
# #SampleID
# 550.L1S1.s.1.sequence                                       sample_1 stool
# 550.L1S10.s.1.sequence                                      sample_2 stool
# 550.L1S100.s.1.sequence                                     sample_3 stool
# 550.L1S101.s.1.sequence                                     sample_4 stool
# 550.L1S102.s.1.sequence                                     sample_5 stool
# 550.L1S103.s.1.sequence                                     sample_6 stool
# 550.L1S104.s.1.sequence                                     sample_7 stool
# 550.L1S105.s.1.sequence                                     sample_8 stool
# 550.L1S106.s.1.sequence                                     sample_9 stool
# 550.L1S107.s.1.sequence                                    sample_10 stool
# 550.L1S108.s.1.sequence                                    sample_11 stool
# 550.L1S109.s.1.sequence                                    sample_12 stool
# 550.L1S11.s.1.sequence                                     sample_13 stool
# 550.L1S110.s.1.sequence                                    sample_14 stool
# 550.L1S111.s.1.sequence                                    sample_15 stool
# 550.L1S112.s.1.sequence                                    sample_16 stool
# 550.L1S113.s.1.sequence                                    sample_17 stool
# 550.L1S114.s.1.sequence                                    sample_18 stool
# 550.L1S115.s.1.sequence                                    sample_19 stool
# 550.L1S116.s.1.sequence                                    sample_20 stool
# 550.L1S117.s.1.sequence                                    sample_21 stool
# 550.L1S118.s.1.sequence                                    sample_22 stool
# 550.L1S119.s.1.sequence                                    sample_23 stool
# 550.L1S12.s.1.sequence                                     sample_24 stool
# 550.L1S120.s.1.sequence                                    sample_25 stool
# 550.L1S121.s.1.sequence                                    sample_26 stool
# 550.L1S122.s.1.sequence                                    sample_27 stool
# 550.L1S123.s.1.sequence                                    sample_28 stool
# 550.L1S124.s.1.sequence                                    sample_29 stool
# 550.L1S125.s.1.sequence                                    sample_30 stool
# 550.L1S126.s.1.sequence                                    sample_31 stool
# 550.L1S127.s.1.sequence                                    sample_32 stool
# 550.L1S128.s.1.sequence                                    sample_33 stool
# 550.L1S129.s.1.sequence                                    sample_34 stool
# 550.L1S13.s.1.sequence                                     sample_35 stool
# 550.L1S130.s.1.sequence                                    sample_36 stool
# 550.L1S131.s.1.sequence                                    sample_37 stool
# 550.L1S132.s.1.sequence                                    sample_38 stool
# 550.L1S133.s.1.sequence                                    sample_39 stool
# 550.L1S134.s.1.sequence                                    sample_40 stool
# 550.L1S135.s.1.sequence                                    sample_41 stool
# 550.L1S136.s.1.sequence                                    sample_42 stool
# 550.L1S137.s.1.sequence                                    sample_43 stool
# 550.L1S138.s.1.sequence                                    sample_44 stool
# 550.L1S139.s.1.sequence                                    sample_45 stool
# 550.L1S14.s.1.sequence                                     sample_46 stool
# 550.L1S140.s.1.sequence                                    sample_47 stool
# 550.L1S141.s.1.sequence                                    sample_48 stool
# 550.L1S142.s.1.sequence                                    sample_49 stool
# 550.L1S143.s.1.sequence                                    sample_50 stool
# 550.L1S144.s.1.sequence                                    sample_51 stool
# 550.L1S145.s.1.sequence                                    sample_52 stool
# 550.L1S146.s.1.sequence                                    sample_53 stool
# 550.L1S147.s.1.sequence                                    sample_54 stool
# 550.L1S148.s.1.sequence                                    sample_55 stool
# 550.L1S149.s.1.sequence                                    sample_56 stool
# 550.L1S15.s.1.sequence                                     sample_57 stool
# 550.L1S150.s.1.sequence                                    sample_58 stool
# 550.L1S151.s.1.sequence                                    sample_59 stool
# 550.L1S152.s.1.sequence                                    sample_60 stool
# 550.L1S153.s.1.sequence                                    sample_61 stool
# 550.L1S154.s.1.sequence                                    sample_62 stool
# 550.L1S155.s.1.sequence                                    sample_63 stool
# 550.L1S156.s.1.sequence                                    sample_64 stool
# 550.L1S157.s.1.sequence                                    sample_65 stool
# 550.L1S158.s.1.sequence                                    sample_66 stool
# 550.L1S159.s.1.sequence                                    sample_67 stool
# 550.L1S16.s.1.sequence                                     sample_68 stool
# 550.L1S160.s.1.sequence                                    sample_69 stool
# 550.L1S161.s.1.sequence                                    sample_70 stool
# 550.L1S162.s.1.sequence                                    sample_71 stool
# 550.L1S163.s.1.sequence                                    sample_72 stool
# 550.L1S164.s.1.sequence                                    sample_73 stool
# 550.L1S165.s.1.sequence                                    sample_74 stool
# 550.L1S166.s.1.sequence                                    sample_75 stool
# 550.L1S167.s.1.sequence                                    sample_76 stool
# 550.L1S168.s.1.sequence                                    sample_77 stool
# 550.L1S169.s.1.sequence                                    sample_78 stool
# 550.L1S17.s.1.sequence                                     sample_79 stool
# 550.L1S170.s.1.sequence                                    sample_80 stool
# 550.L1S171.s.1.sequence                                    sample_81 stool
# 550.L1S172.s.1.sequence                                    sample_82 stool
# 550.L1S173.s.1.sequence                                    sample_83 stool
# 550.L1S174.s.1.sequence                                    sample_84 stool
# 550.L1S175.s.1.sequence                                    sample_85 stool
# 550.L1S176.s.1.sequence                                    sample_86 stool
# 550.L1S177.s.1.sequence                                    sample_87 stool
# 550.L1S178.s.1.sequence                                    sample_88 stool
# 550.L1S179.s.1.sequence                                    sample_89 stool
# 550.L1S18.s.1.sequence                                     sample_90 stool
# 550.L1S180.s.1.sequence                                    sample_91 stool
# 550.L1S181.s.1.sequence                                    sample_92 stool
# 550.L1S182.s.1.sequence                                    sample_93 stool
# 550.L1S183.s.1.sequence                                    sample_94 stool
# 550.L1S184.s.1.sequence                                    sample_95 stool
# 550.L1S185.s.1.sequence                                    sample_96 stool
# 550.L1S186.s.1.sequence                                    sample_97 stool
# 550.L1S187.s.1.sequence                                    sample_98 stool
# 550.L1S188.s.1.sequence                                    sample_99 stool
# 550.L1S189.s.1.sequence                                   sample_100 stool
# ...                                                                    ...
# 10346.Webster.5.D10.422                            Suberites diversicolour
# 10346.Webster.5.D11.423                            Suberites diversicolour
# 10346.Webster.5.D12.424                            Suberites diversicolour
# 10346.Webster.5.D1.413                             Suberites diversicolour
# 10346.Webster.5.D2.414                             Suberites diversicolour
# 10346.Webster.5.D3.415                             Suberites diversicolour
# 10346.Webster.5.D4.416                             Suberites diversicolour
# 10346.Webster.5.D5.417                             Suberites diversicolour
# 10346.Webster.5.D6.418                             Suberites diversicolour
# 10346.Webster.5.D7.419                             Suberites diversicolour
# 10346.Webster.5.D8.420                             Suberites diversicolour
# 10346.Webster.5.D9.421                             Suberites diversicolour
# 10346.Webster.5.E1.425                             Suberites diversicolour
# 10346.Webster.5.E2.426                             Suberites diversicolour
# 10346.Webster.5.E3.427                                Seawater Davies Reef
# 10346.Webster.5.E4.428                                Seawater Davies Reef
# 10346.Webster.5.E5.429                                Seawater Davies Reef
# 10346.Webster.5.E6.430                                Seawater Davies Reef
# 10346.ZA.12                                           euphotic reef sponge
# 10346.ZA.13                                           euphotic reef sponge
# 10346.ZA.14                                           euphotic reef sponge
# 10346.ZA.15                                           euphotic reef sponge
# 10346.ZA.16                                           euphotic reef sponge
# 10346.ZA.17                                           euphotic reef sponge
# 10346.ZA.37                                           euphotic reef sponge
# 10346.ZA.38                                           euphotic reef sponge
# 10346.ZA.39                                           euphotic reef sponge
# 10346.ZA.40                                           euphotic reef sponge
# 10346.ZA.41                                           euphotic reef sponge
# 10346.ZA.42                                           euphotic reef sponge
# 10346.ZA.44                                           euphotic reef sponge
# 10346.ZA.46                                           euphotic reef sponge
# 10346.ZA.47                                           euphotic reef sponge
# 10346.ZA.48                                           euphotic reef sponge
# 10346.ZA.49                                           euphotic reef sponge
# 10346.ZA.53                                           euphotic reef sponge
# 10363.AC1                   Stanleya pinnata HA, Pine Ridge (seleniferous)
# 10363.AC10               Astragalus bisulcatus HA, Pine Ridge (selenife...
# 10363.AC11               Astragalus bisulcatus HA, Pine Ridge (selenife...
# 10363.AC12               Astragalus bisulcatus HA, Pine Ridge (selenife...
# 10363.AC13               Symphyotrichum ericoides HA, Pine Ridge (selen...
# 10363.AC14               Symphyotrichum ericoides HA, Pine Ridge (selen...
# 10363.AC15               Symphyotrichum ericoides HA, Pine Ridge (selen...
# 10363.AC16               Symphyotrichum ericoides HA, Pine Ridge (selen...
# 10363.AC17               Symphyotrichum ericoides HA, Pine Ridge (selen...
# 10363.AC18               Symphyotrichum ericoides HA, Pine Ridge (selen...
# 10363.AC19               Physaria bellii non HA, Pine Ridge (seleniferous)
# 10363.AC2                   Stanleya pinnata HA, Pine Ridge (seleniferous)
# 10363.AC20               Physaria bellii non HA, Pine Ridge (seleniferous)
# 10363.AC21               Physaria bellii non HA, Pine Ridge (seleniferous)
# 10363.AC22               Physaria bellii non HA, Pine Ridge (seleniferous)
# 10363.AC23               Physaria bellii non HA, Pine Ridge (seleniferous)
# 10363.AC24               Physaria bellii non HA, Pine Ridge (seleniferous)
# 10363.AC25               Astragalus tenellus non HA, Pine Ridge (seleni...
# 10363.AC26               Astragalus tenellus non HA, Pine Ridge (seleni...
# 10363.AC27               Astragalus tenellus non HA, Pine Ridge (seleni...
# 10363.AC28               Astragalus tenellus non HA, Pine Ridge (seleni...
# 10363.AC29               BULK SOIL (unvegetated) N/A, Pine Ridge (selen...
# 10363.AC3                   Stanleya pinnata HA, Pine Ridge (seleniferous)
# 10363.AC30               BULK SOIL (unvegetated) N/A, Pine Ridge (selen...
# 10363.AC31               BULK SOIL (unvegetated) N/A, Pine Ridge (selen...
# 10363.AC32               BULK SOIL (unvegetated) N/A, Pine Ridge (selen...
# 10363.AC33               BULK SOIL (unvegetated) N/A, Pine Ridge (selen...
# 10363.AC34               BULK SOIL (unvegetated) N/A, Pine Ridge (selen...
# 10363.AC35               Symphyotrichum ericoides non HA, Cloudy Pass (...
# 10363.AC36               Symphyotrichum ericoides non HA, Cloudy Pass (...
# 10363.AC37               Symphyotrichum ericoides non HA, Cloudy Pass (...
# 10363.AC38               Symphyotrichum ericoides non HA, Cloudy Pass (...
# 10363.AC39               Symphyotrichum ericoides non HA, Cloudy Pass (...
# 10363.AC4                   Stanleya pinnata HA, Pine Ridge (seleniferous)
# 10363.AC40               Symphyotrichum ericoides non HA, Cloudy Pass (...
# 10363.AC41               Physaria bellii non HA, Cloudy Pass (non-selen...
# 10363.AC42               Physaria bellii non HA, Cloudy Pass (non-selen...
# 10363.AC43               Physaria bellii non HA, Cloudy Pass (non-selen...
# 10363.AC44               Physaria bellii non HA, Cloudy Pass (non-selen...
# 10363.AC45               Physaria bellii non HA, Cloudy Pass (non-selen...
# 10363.AC46               Physaria bellii non HA, Cloudy Pass (non-selen...
# 10363.AC47               Astragalus sp non HA, Cloudy Pass (non-selenif...
# 10363.AC48               Astragalus sp non HA, Cloudy Pass (non-selenif...
# 10363.AC49               Astragalus sp non HA, Cloudy Pass (non-selenif...
# 10363.AC5                   Stanleya pinnata HA, Pine Ridge (seleniferous)
# 10363.AC50               Astragalus sp non HA, Cloudy Pass (non-selenif...
# 10363.AC51               Astragalus sp non HA, Cloudy Pass (non-selenif...
# 10363.AC52               Astragalus sp non HA, Cloudy Pass (non-selenif...
# 10363.AC53               BULK SOIL (unvegetated) N/A, Cloudy Pass (non-...
# 10363.AC54               BULK SOIL (unvegetated) N/A, Cloudy Pass (non-...
# 10363.AC55               BULK SOIL (unvegetated) N/A, Cloudy Pass (non-...
# 10363.AC56               BULK SOIL (unvegetated) N/A, Cloudy Pass (non-...
# 10363.AC57               BULK SOIL (unvegetated) N/A, Cloudy Pass (non-...
# 10363.AC58               BULK SOIL (unvegetated) N/A, Cloudy Pass (non-...
# 10363.AC6                   Stanleya pinnata HA, Pine Ridge (seleniferous)
# 10363.AC7                Astragalus bisulcatus HA, Pine Ridge (selenife...
# 10363.AC8                Astragalus bisulcatus HA, Pine Ridge (selenife...
# 10363.AC9                Astragalus bisulcatus HA, Pine Ridge (selenife...
# 10363.BLANK.CSU1.8C                                          BLANK.CSU1.8C
# 10363.BLANK.CSU1.8D                                          BLANK.CSU1.8D
# 10363.BLANK.CSU1.8E                                          BLANK.CSU1.8E
# 10363.BLANK.CSU1.8F                                          BLANK.CSU1.8F
# 10363.BLANK.CSU1.8G                                          BLANK.CSU1.8G
# 10363.BLANK.CSU1.8H                                          BLANK.CSU1.8H
#
#                            host_subject_id study_id  \
# #SampleID
# 550.L1S1.s.1.sequence                   F4      550
# 550.L1S10.s.1.sequence                  F4      550
# 550.L1S100.s.1.sequence                 F4      550
# 550.L1S101.s.1.sequence                 F4      550
# 550.L1S102.s.1.sequence                 F4      550
# 550.L1S103.s.1.sequence                 F4      550
# 550.L1S104.s.1.sequence                 F4      550
# 550.L1S105.s.1.sequence                 F4      550
# 550.L1S106.s.1.sequence                 F4      550
# 550.L1S107.s.1.sequence                 F4      550
# 550.L1S108.s.1.sequence                 F4      550
# 550.L1S109.s.1.sequence                 F4      550
# 550.L1S11.s.1.sequence                  F4      550
# 550.L1S110.s.1.sequence                 F4      550
# 550.L1S111.s.1.sequence                 F4      550
# 550.L1S112.s.1.sequence                 F4      550
# 550.L1S113.s.1.sequence                 F4      550
# 550.L1S114.s.1.sequence                 F4      550
# 550.L1S115.s.1.sequence                 F4      550
# 550.L1S116.s.1.sequence                 F4      550
# 550.L1S117.s.1.sequence                 F4      550
# 550.L1S118.s.1.sequence                 F4      550
# 550.L1S119.s.1.sequence                 F4      550
# 550.L1S12.s.1.sequence                  F4      550
# 550.L1S120.s.1.sequence                 F4      550
# 550.L1S121.s.1.sequence                 F4      550
# 550.L1S122.s.1.sequence                 F4      550
# 550.L1S123.s.1.sequence                 F4      550
# 550.L1S124.s.1.sequence                 F4      550
# 550.L1S125.s.1.sequence                 F4      550
# 550.L1S126.s.1.sequence                 F4      550
# 550.L1S127.s.1.sequence                 F4      550
# 550.L1S128.s.1.sequence                 F4      550
# 550.L1S129.s.1.sequence                 F4      550
# 550.L1S13.s.1.sequence                  F4      550
# 550.L1S130.s.1.sequence                 F4      550
# 550.L1S131.s.1.sequence                 F4      550
# 550.L1S132.s.1.sequence                 F4      550
# 550.L1S133.s.1.sequence                 M3      550
# 550.L1S134.s.1.sequence                 M3      550
# 550.L1S135.s.1.sequence                 M3      550
# 550.L1S136.s.1.sequence                 M3      550
# 550.L1S137.s.1.sequence                 M3      550
# 550.L1S138.s.1.sequence                 M3      550
# 550.L1S139.s.1.sequence                 M3      550
# 550.L1S14.s.1.sequence                  F4      550
# 550.L1S140.s.1.sequence                 M3      550
# 550.L1S141.s.1.sequence                 M3      550
# 550.L1S142.s.1.sequence                 M3      550
# 550.L1S143.s.1.sequence                 M3      550
# 550.L1S144.s.1.sequence                 M3      550
# 550.L1S145.s.1.sequence                 M3      550
# 550.L1S146.s.1.sequence                 M3      550
# 550.L1S147.s.1.sequence                 M3      550
# 550.L1S148.s.1.sequence                 M3      550
# 550.L1S149.s.1.sequence                 M3      550
# 550.L1S15.s.1.sequence                  F4      550
# 550.L1S150.s.1.sequence                 M3      550
# 550.L1S151.s.1.sequence                 M3      550
# 550.L1S152.s.1.sequence                 M3      550
# 550.L1S153.s.1.sequence                 M3      550
# 550.L1S154.s.1.sequence                 M3      550
# 550.L1S155.s.1.sequence                 M3      550
# 550.L1S156.s.1.sequence                 M3      550
# 550.L1S157.s.1.sequence                 M3      550
# 550.L1S158.s.1.sequence                 M3      550
# 550.L1S159.s.1.sequence                 M3      550
# 550.L1S16.s.1.sequence                  F4      550
# 550.L1S160.s.1.sequence                 M3      550
# 550.L1S161.s.1.sequence                 M3      550
# 550.L1S162.s.1.sequence                 M3      550
# 550.L1S163.s.1.sequence                 M3      550
# 550.L1S164.s.1.sequence                 M3      550
# 550.L1S165.s.1.sequence                 M3      550
# 550.L1S166.s.1.sequence                 M3      550
# 550.L1S167.s.1.sequence                 M3      550
# 550.L1S168.s.1.sequence                 M3      550
# 550.L1S169.s.1.sequence                 M3      550
# 550.L1S17.s.1.sequence                  F4      550
# 550.L1S170.s.1.sequence                 M3      550
# 550.L1S171.s.1.sequence                 M3      550
# 550.L1S172.s.1.sequence                 M3      550
# 550.L1S173.s.1.sequence                 M3      550
# 550.L1S174.s.1.sequence                 M3      550
# 550.L1S175.s.1.sequence                 M3      550
# 550.L1S176.s.1.sequence                 M3      550
# 550.L1S177.s.1.sequence                 M3      550
# 550.L1S178.s.1.sequence                 M3      550
# 550.L1S179.s.1.sequence                 M3      550
# 550.L1S18.s.1.sequence                  F4      550
# 550.L1S180.s.1.sequence                 M3      550
# 550.L1S181.s.1.sequence                 M3      550
# 550.L1S182.s.1.sequence                 M3      550
# 550.L1S183.s.1.sequence                 M3      550
# 550.L1S184.s.1.sequence                 M3      550
# 550.L1S185.s.1.sequence                 M3      550
# 550.L1S186.s.1.sequence                 M3      550
# 550.L1S187.s.1.sequence                 M3      550
# 550.L1S188.s.1.sequence                 M3      550
# 550.L1S189.s.1.sequence                 M3      550
# ...                                    ...      ...
# 10346.Webster.5.D10.422  Webster.5.D10.422    10346
# 10346.Webster.5.D11.423  Webster.5.D11.423    10346
# 10346.Webster.5.D12.424  Webster.5.D12.424    10346
# 10346.Webster.5.D1.413    Webster.5.D1.413    10346
# 10346.Webster.5.D2.414    Webster.5.D2.414    10346
# 10346.Webster.5.D3.415    Webster.5.D3.415    10346
# 10346.Webster.5.D4.416    Webster.5.D4.416    10346
# 10346.Webster.5.D5.417    Webster.5.D5.417    10346
# 10346.Webster.5.D6.418    Webster.5.D6.418    10346
# 10346.Webster.5.D7.419    Webster.5.D7.419    10346
# 10346.Webster.5.D8.420    Webster.5.D8.420    10346
# 10346.Webster.5.D9.421    Webster.5.D9.421    10346
# 10346.Webster.5.E1.425    Webster.5.E1.425    10346
# 10346.Webster.5.E2.426    Webster.5.E2.426    10346
# 10346.Webster.5.E3.427    Webster.5.E3.427    10346
# 10346.Webster.5.E4.428    Webster.5.E4.428    10346
# 10346.Webster.5.E5.429    Webster.5.E5.429    10346
# 10346.Webster.5.E6.430    Webster.5.E6.430    10346
# 10346.ZA.12                          ZA.12    10346
# 10346.ZA.13                          ZA.13    10346
# 10346.ZA.14                          ZA.14    10346
# 10346.ZA.15                          ZA.15    10346
# 10346.ZA.16                          ZA.16    10346
# 10346.ZA.17                          ZA.17    10346
# 10346.ZA.37                          ZA.37    10346
# 10346.ZA.38                          ZA.38    10346
# 10346.ZA.39                          ZA.39    10346
# 10346.ZA.40                          ZA.40    10346
# 10346.ZA.41                          ZA.41    10346
# 10346.ZA.42                          ZA.42    10346
# 10346.ZA.44                          ZA.44    10346
# 10346.ZA.46                          ZA.46    10346
# 10346.ZA.47                          ZA.47    10346
# 10346.ZA.48                          ZA.48    10346
# 10346.ZA.49                          ZA.49    10346
# 10346.ZA.53                          ZA.53    10346
# 10363.AC1                           AC_Sp1    10363
# 10363.AC10                          AC_Ab8    10363
# 10363.AC11                         AC_Ab10    10363
# 10363.AC12                         AC_Ab11    10363
# 10363.AC13                          AC_Se1    10363
# 10363.AC14                          AC_Se2    10363
# 10363.AC15                         AC_Se10    10363
# 10363.AC16                         AC_Se14    10363
# 10363.AC17                         AC_Se15    10363
# 10363.AC18                         AC_Se16    10363
# 10363.AC19                          AC_Pb5    10363
# 10363.AC2                           AC_Sp2    10363
# 10363.AC20                          AC_Pb6    10363
# 10363.AC21                          AC_Pb7    10363
# 10363.AC22                         AC_Pb11    10363
# 10363.AC23                         AC_Pb12    10363
# 10363.AC24                         AC_Pb13    10363
# 10363.AC25                          AC_At1    10363
# 10363.AC26                          AC_At2    10363
# 10363.AC27                          AC_Ab7    10363
# 10363.AC28                          AC_Ab9    10363
# 10363.AC29                          AC_BS7    10363
# 10363.AC3                           AC_Sp3    10363
# 10363.AC30                          AC_BS8    10363
# 10363.AC31                          AC_BS9    10363
# 10363.AC32                         AC_BS10    10363
# 10363.AC33                         AC_BS11    10363
# 10363.AC34                         AC_BS12    10363
# 10363.AC35                          AC_Se7    10363
# 10363.AC36                          AC_Se8    10363
# 10363.AC37                          AC_Se9    10363
# 10363.AC38                         AC_Se11    10363
# 10363.AC39                         AC_Se12    10363
# 10363.AC4                           AC_Sp4    10363
# 10363.AC40                         AC_Se13    10363
# 10363.AC41                          AC_Pb1    10363
# 10363.AC42                          AC_Pb3    10363
# 10363.AC43                          AC_Pb4    10363
# 10363.AC44                          AC_Pb8    10363
# 10363.AC45                          AC_Pb9    10363
# 10363.AC46                         AC_Pb10    10363
# 10363.AC47                          AC_As1    10363
# 10363.AC48                          AC_As2    10363
# 10363.AC49                          AC_As3    10363
# 10363.AC5                           AC_Sp5    10363
# 10363.AC50                          AC_As4    10363
# 10363.AC51                          AC_As5    10363
# 10363.AC52                          AC_As6    10363
# 10363.AC53                          AC_BS1    10363
# 10363.AC54                          AC_BS2    10363
# 10363.AC55                          AC_BS3    10363
# 10363.AC56                          AC_BS4    10363
# 10363.AC57                          AC_BS5    10363
# 10363.AC58                          AC_BS6    10363
# 10363.AC6                           AC_Sp6    10363
# 10363.AC7                           AC_Ab1    10363
# 10363.AC8                           AC_Ab2    10363
# 10363.AC9                           AC_Ab3    10363
# 10363.BLANK.CSU1.8C          BLANK.CSU1.8C    10363
# 10363.BLANK.CSU1.8D          BLANK.CSU1.8D    10363
# 10363.BLANK.CSU1.8E          BLANK.CSU1.8E    10363
# 10363.BLANK.CSU1.8F          BLANK.CSU1.8F    10363
# 10363.BLANK.CSU1.8G          BLANK.CSU1.8G    10363
# 10363.BLANK.CSU1.8H          BLANK.CSU1.8H    10363
#
#                                                                      title  \
# #SampleID
# 550.L1S1.s.1.sequence              Moving pictures of the human microbiome
# 550.L1S10.s.1.sequence             Moving pictures of the human microbiome
# 550.L1S100.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S101.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S102.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S103.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S104.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S105.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S106.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S107.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S108.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S109.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S11.s.1.sequence             Moving pictures of the human microbiome
# 550.L1S110.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S111.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S112.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S113.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S114.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S115.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S116.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S117.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S118.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S119.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S12.s.1.sequence             Moving pictures of the human microbiome
# 550.L1S120.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S121.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S122.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S123.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S124.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S125.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S126.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S127.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S128.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S129.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S13.s.1.sequence             Moving pictures of the human microbiome
# 550.L1S130.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S131.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S132.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S133.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S134.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S135.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S136.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S137.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S138.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S139.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S14.s.1.sequence             Moving pictures of the human microbiome
# 550.L1S140.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S141.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S142.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S143.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S144.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S145.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S146.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S147.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S148.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S149.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S15.s.1.sequence             Moving pictures of the human microbiome
# 550.L1S150.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S151.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S152.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S153.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S154.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S155.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S156.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S157.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S158.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S159.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S16.s.1.sequence             Moving pictures of the human microbiome
# 550.L1S160.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S161.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S162.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S163.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S164.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S165.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S166.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S167.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S168.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S169.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S17.s.1.sequence             Moving pictures of the human microbiome
# 550.L1S170.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S171.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S172.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S173.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S174.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S175.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S176.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S177.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S178.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S179.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S18.s.1.sequence             Moving pictures of the human microbiome
# 550.L1S180.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S181.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S182.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S183.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S184.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S185.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S186.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S187.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S188.s.1.sequence            Moving pictures of the human microbiome
# 550.L1S189.s.1.sequence            Moving pictures of the human microbiome
# ...
# 550.L1S102.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S103.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S104.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S105.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S106.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S107.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S108.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S109.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S11.s.1.sequence     Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S110.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S111.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S112.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S113.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S114.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S115.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S116.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S117.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S118.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S119.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S12.s.1.sequence     Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S120.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S121.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S122.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S123.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S124.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S125.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S126.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S127.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S128.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S129.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S13.s.1.sequence     Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S130.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S131.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S132.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S133.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S134.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S135.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S136.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S137.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S138.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S139.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S14.s.1.sequence     Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S140.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S141.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S142.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S143.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S144.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S145.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S146.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S147.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S148.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S149.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S15.s.1.sequence     Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S150.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S151.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S152.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S153.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S154.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S155.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S156.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S157.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S158.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S159.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S16.s.1.sequence     Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S160.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S161.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S162.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S163.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S164.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S165.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S166.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S167.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S168.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S169.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S17.s.1.sequence     Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S170.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S171.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S172.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S173.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S174.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S175.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S176.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S177.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S178.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S179.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S18.s.1.sequence     Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S180.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S181.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S182.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S183.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S184.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S185.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S186.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S187.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S188.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# 550.L1S189.s.1.sequence    Animal distal gut         NaN   NaN      NaN    NaN
# ...                                      ...         ...   ...      ...    ...
# 10346.Webster.5.D10.422        Animal corpus        28.5  7.67     36.5    NaN
# 10346.Webster.5.D11.423        Animal corpus        28.5  7.67     36.5    NaN
# 10346.Webster.5.D12.424        Animal corpus          29  7.67     36.5    NaN
# 10346.Webster.5.D1.413         Animal corpus          28  7.67     36.5    NaN
# 10346.Webster.5.D2.414         Animal corpus          28  7.67     36.5    NaN
# 10346.Webster.5.D3.415         Animal corpus        29.5  7.67     36.5    NaN
# 10346.Webster.5.D4.416         Animal corpus        29.5  7.67     36.5    NaN
# 10346.Webster.5.D5.417         Animal corpus        29.5  7.67     36.5    NaN
# 10346.Webster.5.D6.418         Animal corpus          29  7.67     36.5    NaN
# 10346.Webster.5.D7.419         Animal corpus          29  7.67     36.5    NaN
# 10346.Webster.5.D8.420         Animal corpus          29  7.67     36.5    NaN
# 10346.Webster.5.D9.421         Animal corpus        28.5  7.67     36.5    NaN
# 10346.Webster.5.E1.425         Animal corpus          29  7.67     36.5    NaN
# 10346.Webster.5.E2.426         Animal corpus          29  7.67     36.5    NaN
# 10346.Webster.5.E3.427        Water (saline)        23.5   NaN      NaN    NaN
# 10346.Webster.5.E4.428        Water (saline)        23.5   NaN      NaN    NaN
# 10346.Webster.5.E5.429        Water (saline)        23.5   NaN      NaN    NaN
# 10346.Webster.5.E6.430        Water (saline)        23.5   NaN      NaN    NaN
# 10346.ZA.12                    Animal corpus          27   NaN      NaN    NaN
# 10346.ZA.13                    Animal corpus          27   NaN      NaN    NaN
# 10346.ZA.14                    Animal corpus          27   NaN      NaN    NaN
# 10346.ZA.15                    Animal corpus          27   NaN      NaN    NaN
# 10346.ZA.16                    Animal corpus          27   NaN      NaN    NaN
# 10346.ZA.17                    Animal corpus          27   NaN      NaN    NaN
# 10346.ZA.37                    Animal corpus          27   NaN      NaN    NaN
# 10346.ZA.38                    Animal corpus          27   NaN      NaN    NaN
# 10346.ZA.39                    Animal corpus          27   NaN      NaN    NaN
# 10346.ZA.40                    Animal corpus          27   NaN      NaN    NaN
# 10346.ZA.41                    Animal corpus          27   NaN      NaN    NaN
# 10346.ZA.42                    Animal corpus          27   NaN      NaN    NaN
# 10346.ZA.44                    Animal corpus          27   NaN      NaN    NaN
# 10346.ZA.46                    Animal corpus          27   NaN      NaN    NaN
# 10346.ZA.47                    Animal corpus          27   NaN      NaN    NaN
# 10346.ZA.48                    Animal corpus          27   NaN      NaN    NaN
# 10346.ZA.49                    Animal corpus          27   NaN      NaN    NaN
# 10346.ZA.53                    Animal corpus          27   NaN      NaN    NaN
# 10363.AC1                  Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC10                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC11                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC12                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC13                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC14                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC15                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC16                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC17                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC18                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC19                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC2                  Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC20                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC21                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC22                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC23                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC24                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC25                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC26                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC27                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC28                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC29                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC3                  Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC30                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC31                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC32                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC33                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC34                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC35                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC36                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC37                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC38                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC39                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC4                  Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC40                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC41                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC42                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC43                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC44                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC45                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC46                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC47                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC48                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC49                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC5                  Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC50                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC51                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC52                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC53                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC54                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC55                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC56                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC57                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC58                 Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC6                  Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC7                  Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC8                  Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.AC9                  Soil (non-saline)         NaN   NaN      NaN    NaN
# 10363.BLANK.CSU1.8C      Sterile water blank         NaN   NaN      NaN    NaN
# 10363.BLANK.CSU1.8D      Sterile water blank         NaN   NaN      NaN    NaN
# 10363.BLANK.CSU1.8E      Sterile water blank         NaN   NaN      NaN    NaN
# 10363.BLANK.CSU1.8F      Sterile water blank         NaN   NaN      NaN    NaN
# 10363.BLANK.CSU1.8G      Sterile water blank         NaN   NaN      NaN    NaN
# 10363.BLANK.CSU1.8H      Sterile water blank         NaN   NaN      NaN    NaN
#
# [34007 rows x 35 columns]

# %%
# reorder columns
cols = ['Total',
        'Animal corpus', 
        'Animal distal gut', 
        'Animal proximal gut', 
        'Animal secretion', 
        'Animal surface', 
        'Plant corpus', 
        'Plant rhizosphere', 
        'Plant surface', 
        'Soil (non-saline)', 
        'Sediment (non-saline)', 
        'Surface (non-saline)', 
        'Water (non-saline)', 
        'Aerosol (non-saline)', 
        'Sediment (saline)', 
        'Surface (saline)', 
        'Water (saline)',
        'Intertidal (saline)', 
        'Hypersaline (saline)']
studies_groupby_unstack = studies_groupby_unstack[cols]

# %%
studies_groupby_unstack = pd.DataFrame(data=studies_groupby_unstack.fillna(0), dtype=int)
studies_groupby_unstack_sorted = studies_groupby_unstack['Total'].sort_values(ascending=False)

# %%
plt.figure(figsize=(20,5))
ph = sns.barplot(studies_groupby_unstack_sorted.index, studies_groupby_unstack_sorted)
for item in ph.get_xticklabels():
    item.set_rotation(45)

# %% [markdown]
# ### Write merged refined mapping file

# %%
today = datetime.datetime.today()
df_refined.to_csv('/Users/luke/emp/metadata-refine/emp_qiime_mapping_refined_%s.tsv' % today.strftime('%Y%m%d'), sep='\t')

# %% [markdown]
# ### Write list of studies

# %%
studies_groupby_unstack.to_csv('/Users/luke/emp/metadata-refine/emp_studies_no_controls_%s.tsv' % today.strftime('%Y%m%d'), sep='\t')

# %% [markdown]
# ### Split and write individual refined mapping files

# %%
studies = [line.rstrip('\n') for line in open(path_studies)]
for study in studies:
    df_individual = df_refined[df_refined.study_id == study]
    df_individual.to_csv('/Users/luke/emp/metadata-refine/qiime-maps-refined/%s_qiime_mapping_refined.tsv' % study, sep='\t')
